# %%
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow_probability import distributions as tfd
from tensorflow_probability import layers as tfpl
from tensorflow_probability import math as tfpm
# Out:
# 2023-05-10 16:40:51.516594: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-10 16:40:51.605909: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
import pandas as pd
from pathlib import Path
from matplotlib import pyplot as plt
from matplotlib import cm
import matplotlib.dates as mdates
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder,StandardScaler
import seaborn as sbn

# %%
SOURCE = Path('/mnt/data extra/DATASET/PREDICTION_DATA')
DATA_22 = SOURCE.joinpath('unidad de medida 2022').with_suffix('.csv')
DATA_23 = SOURCE.joinpath('unidad de medida 2023').with_suffix('.csv')

# %% [markdown]
# ## Preparacion de cargar y analizar datos modelo

# %% [markdown]
# Cargar y Concatenar informacion

# %%
data_complete_22 = pd.read_csv(str(DATA_22),header=[0])
data_complete_22.drop(0,axis=0,inplace=True)
data_complete_23 = pd.read_csv(str(DATA_23),header=[0])
data_complete_23.drop(0,axis=0,inplace=True)
data_complete = pd.concat([data_complete_22,data_complete_23])
data_complete.reset_index(drop=True,inplace=True)
display(data_complete.head())
# Out:
# /tmp/ipykernel_25701/1143381664.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_complete_22 = pd.read_csv(str(DATA_22),header=[0])
#   Fecha Creación                        Material  Material (Cod)  \
# 0       1/1/2022  Cemento Fuerte Ecoplanet 50 kg      10011308.0
# 1       1/2/2022  Cemento Fuerte Ecoplanet 50 kg      10011308.0
# 2       1/3/2022    CEMENTO ESPECIAL PLUS (ESP+)      10059053.0
# 3       1/3/2022    CEMENTO ESPECIAL PLUS (ESP+)      10059053.0
# 4       1/3/2022    CEMENTO ESPECIAL PLUS (ESP+)      10059053.0
#
#    Peso neto (TON)                          Solicitate Solicitate (Cod)  \
# 0            10.00        HECTOR QUINTANILLA BALAGUERA       0004155696
# 1            10.00  FERRETERIA EL FERROL/ CHIQUINQUIRA       0004158888
# 2            34.19                  PLANTA SUR CREDITO       0004151082
# 3            33.33                      PLANTA MILENIO       0004139983
# 4            33.61             PLANTA NEREIDAS CREDITO       0004150188
#
#   Unidad Medida Base Unidad Medida Venta Cant Pedido UMV Valor Neto  \
# 0                 TO                 SAC           200.0    3,844.5
# 1                 TO                 SAC           200.0    3,939.1
# 2                 TO                  TO            34.2   11,863.9
# 3                 TO                  TO            33.3   11,346.9
# 4                 TO                  TO            33.6   11,662.7
#
#   Contador Ped
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %% [markdown]
# Seleccion de columnas

# %%
SELECT_COLUMNS = ['Fecha Creación','Material (Cod)','Peso neto (TON)','Solicitate (Cod)','Cant Pedido UMV','Valor Neto']
data_complete = data_complete[SELECT_COLUMNS]
display(data_complete.head())
# Out:
#   Fecha Creación  Material (Cod)  Peso neto (TON) Solicitate (Cod)  \
# 0       1/1/2022      10011308.0            10.00       0004155696
# 1       1/2/2022      10011308.0            10.00       0004158888
# 2       1/3/2022      10059053.0            34.19       0004151082
# 3       1/3/2022      10059053.0            33.33       0004139983
# 4       1/3/2022      10059053.0            33.61       0004150188
#
#   Cant Pedido UMV Valor Neto
# 0           200.0    3,844.5
# 1           200.0    3,939.1
# 2            34.2   11,863.9
# 3            33.3   11,346.9
# 4            33.6   11,662.7

# %% [markdown]
# Conversion de tipos de datos

# %%
data_complete.dtypes
# Out:
# Fecha Creación       object
# Material (Cod)      float64
# Peso neto (TON)     float64
# Solicitate (Cod)     object
# Cant Pedido UMV      object
# Valor Neto           object
# dtype: object

# %%
data_complete
# Out:
#        Fecha Creación  Material (Cod)  Peso neto (TON) Solicitate (Cod)  \
# 0            1/1/2022      10011308.0           10.000       0004155696
# 1            1/2/2022      10011308.0           10.000       0004158888
# 2            1/3/2022      10059053.0           34.190       0004151082
# 3            1/3/2022      10059053.0           33.330       0004139983
# 4            1/3/2022      10059053.0           33.610       0004150188
# ...               ...             ...              ...              ...
# 105666      3/27/2023      10011308.0           34.500        4125819.0
# 105667      3/27/2023      10011308.0           35.500        4125819.0
# 105668      3/27/2023      10011309.0           34.000        4171362.0
# 105669      3/27/2023      10011309.0           35.020        4171362.0
# 105670      3/27/2023      10011309.0           35.275        4171362.0
#
#        Cant Pedido UMV Valor Neto
# 0                200.0    3,844.5
# 1                200.0    3,939.1
# 2                 34.2   11,863.9
# 3                 33.3   11,346.9
# 4                 33.6   11,662.7
# ...                ...        ...
# 105666           690.0   14,974.4
# 105667           710.0   15,408.4
# 105668         3,200.0   45,146.9
# 105669         2,472.0   34,876.0
# 105670         2,490.0   35,130.0
#
# [105671 rows x 6 columns]

# %%
format = '%m/%d/%Y'
data_complete['Fecha Creación']=pd.to_datetime(data_complete['Fecha Creación'], format=format)
data_complete['Material (Cod)'] = data_complete['Material (Cod)'].apply(lambda x: np.int32(x))
# data_complete['Peso neto (TON)'] = data_complete['Peso neto (TON)'].apply(lambda x: np.float(x))
data_complete['Solicitate (Cod)'] = data_complete['Solicitate (Cod)'].apply(lambda x: str(x))                                                          
data_complete['Cant Pedido UMV'] = data_complete['Cant Pedido UMV'].apply(lambda x: float(x.replace(',','')))
data_complete['Valor Neto'] = data_complete['Valor Neto'].apply(lambda x: float(x.replace(',','')))

# %% [markdown]
# Cambio de nombre

# %%
old = data_complete.columns
new = ['FECHA','MATERIAL','PESO','COMPRADOR','CANTIDAD','VALOR']
data_complete.rename(columns={old_:new_ for old_,new_ in zip(old,new)},inplace=True)
display(data_complete.head())
# Out:
#        FECHA  MATERIAL   PESO   COMPRADOR  CANTIDAD    VALOR
# 0 2022-01-01  10011308  10.00  0004155696     200.0   3844.5
# 1 2022-01-02  10011308  10.00  0004158888     200.0   3939.1
# 2 2022-01-03  10059053  34.19  0004151082      34.2  11863.9
# 3 2022-01-03  10059053  33.33  0004139983      33.3  11346.9
# 4 2022-01-03  10059053  33.61  0004150188      33.6  11662.7

# %%
data_complete.dtypes
# Out:
# FECHA        datetime64[ns]
# MATERIAL              int32
# PESO                float64
# COMPRADOR            object
# CANTIDAD            float64
# VALOR               float64
# dtype: object

# %% [markdown]
# Correcion de la columan de datos de compra para el uso de para cuantificar bien el ID del Comprador por dia

# %%
fix_buyer = []
for index,buyer in enumerate(data_complete.COMPRADOR):
    try:
        fix_buyer.append(str(int(buyer)))
    except:
        
        try:
            fix_buyer.append(str(int(float(buyer))))

        except:
            fix_buyer.append(str(buyer))
        
        
data_complete.COMPRADOR = fix_buyer
display("Lista de compradores")
display(pd.DataFrame(data_complete.COMPRADOR.value_counts()))
# Out:
# 'Lista de compradores'
#          COMPRADOR
# 4102523       3822
# 4177452       1452
# 4169882       1431
# 4177659       1275
# 4103801       1156
# ...            ...
# 4180340          1
# 4181290          1
# 4183823          1
# 4181287          1
# 4185894          1
#
# [2611 rows x 1 columns]

# %% [markdown]
# Numero de materiales que dispone la empresa y cantidad de apariciones de datos a lo largo de 2 anos, con una distribucion de tiempo por dia

# %%
cantidad_materiales = pd.DataFrame(data_complete.MATERIAL.value_counts())
display(cantidad_materiales)
# Out:
#           MATERIAL
# 10011308     38588
# 10070707     14130
# 10059053      6515
# 10011306      5935
# 10011305      2315
# ...            ...
# 96044601         1
# 96018785         1
# 96018801         1
# 96018813         1
# 96050413         1
#
# [2734 rows x 1 columns]

# %% [markdown]
# Separacion de los datos en otras distancia de series de tiempo

# %%
#Cambio de indice
data_complete['Dia'] = data_complete.FECHA.dt.day
data_complete['Mes'] = data_complete.FECHA.dt.month
data_complete['Año'] = data_complete.FECHA.dt.year
data_complete['Semana'] = data_complete.FECHA.dt.isocalendar().week 
data_complete['DiaSemana'] = data_complete.FECHA.dt.day_of_week
display(data_complete)
# Out:
#             FECHA  MATERIAL    PESO COMPRADOR  CANTIDAD    VALOR  Dia  Mes  \
# 0      2022-01-01  10011308  10.000   4155696     200.0   3844.5    1    1
# 1      2022-01-02  10011308  10.000   4158888     200.0   3939.1    2    1
# 2      2022-01-03  10059053  34.190   4151082      34.2  11863.9    3    1
# 3      2022-01-03  10059053  33.330   4139983      33.3  11346.9    3    1
# 4      2022-01-03  10059053  33.610   4150188      33.6  11662.7    3    1
# ...           ...       ...     ...       ...       ...      ...  ...  ...
# 105666 2023-03-27  10011308  34.500   4125819     690.0  14974.4   27    3
# 105667 2023-03-27  10011308  35.500   4125819     710.0  15408.4   27    3
# 105668 2023-03-27  10011309  34.000   4171362    3200.0  45146.9   27    3
# 105669 2023-03-27  10011309  35.020   4171362    2472.0  34876.0   27    3
# 105670 2023-03-27  10011309  35.275   4171362    2490.0  35130.0   27    3
#
#          Año  Semana  DiaSemana
# 0       2022      52          5
# 1       2022      52          6
# 2       2022       1          0
# 3       2022       1          0
# 4       2022       1          0
# ...      ...     ...        ...
# 105666  2023      13          0
# 105667  2023      13          0
# 105668  2023      13          0
# 105669  2023      13          0
# 105670  2023      13          0
#
# [105671 rows x 11 columns]

# %% [markdown]
# # Seleccion de producto y generacion de fecha

# %%
#Cambio de indice
PRODUCTO = 10011308
# data_complete.set_index('FECHA',inplace=True)
df = data_complete[data_complete.MATERIAL == PRODUCTO]

# %%
df.head()
# Out:
#         FECHA  MATERIAL  PESO COMPRADOR  CANTIDAD    VALOR  Dia  Mes   Año  \
# 0  2022-01-01  10011308  10.0   4155696     200.0   3844.5    1    1  2022
# 1  2022-01-02  10011308  10.0   4158888     200.0   3939.1    2    1  2022
# 14 2022-01-03  10011308   5.0   4181050     100.0   2423.4    3    1  2022
# 15 2022-01-03  10011308   5.0   4177946     100.0   2011.2    3    1  2022
# 16 2022-01-03  10011308  35.0   4122784    1400.0  23119.4    3    1  2022
#
#     Semana  DiaSemana
# 0       52          5
# 1       52          6
# 14       1          0
# 15       1          0
# 16       1          0

# %%
df = df.groupby(df.FECHA).sum()
index = pd.date_range(df.index[0],df.index.max())
fill_index = pd.DataFrame([ x for x in range(len(index)) ],index=index)
df = df.reindex(fill_index.index, fill_value=0)
# Out:
# /tmp/ipykernel_25701/3434205304.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = df.groupby(df.FECHA).sum()

# %%
df['DIA'] = df.index.day
df['MES'] = df.index.month
df['ANO'] = df.index.year
df['SEMANA'] = df.index.isocalendar().week 
df['DIASEMANA'] = df.index.day_of_week

# %%
X = df[['DIA','MES','ANO','SEMANA','DIASEMANA']]
Y = df[['CANTIDAD']]

# %%
Y.describe()
# Out:
#             CANTIDAD
# count     451.000000
# mean    55835.226164
# std     37782.714497
# min         0.000000
# 25%     32124.500000
# 50%     61008.000000
# 75%     76732.500000
# max    310201.000000

# %%
fig, ax = plt.subplots(figsize=(40,10))
ax.stem(df.index,df['CANTIDAD'].values)

# Major ticks every 6 months.
fmt_half_year = mdates.MonthLocator(interval=2)
ax.xaxis.set_major_locator(fmt_half_year)

# Minor ticks every month.
fmt_month = mdates.MonthLocator()
ax.xaxis.set_minor_locator(fmt_month)

# Text in the x axis will be displayed in 'YYYY-mm' format.
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# Round to nearest years.
datemin =np.datetime64(df.index.min(), 'Y')
datemax =np.datetime64(df.index.max(), 'Y')
ax.set_xlim(datemin, datemax)

# Format the coords message box, i.e. the numbers displayed as the cursor moves
# across the axes within the interactive GUI.
ax.format_xdata = mdates.DateFormatter('%Y-%m')
# ax.format_ydata = lambda x: f'${x:.2f}'  # Format the price.
ax.grid(True)

# Rotates and right aligns the x labels, and moves the bottom of the
# axes up to make room for them.
fig.autofmt_xdate()

plt.show()

# %%
data_per_weeks = df.groupby([pd.Grouper(freq='W')])['CANTIDAD'].sum()
data_per_weeks = pd.DataFrame(data_per_weeks)

data_per_weeks['MES'] = data_per_weeks.index.month
data_per_weeks['ANO'] = data_per_weeks.index.year
data_per_weeks['SEMANA'] = data_per_weeks.index.isocalendar().week 

display(data_per_weeks)
df = data_per_weeks
# Out:
#             CANTIDAD  MES   ANO  SEMANA
# 2022-01-02     400.0    1  2022      52
# 2022-01-09  281300.0    1  2022       1
# 2022-01-16  293822.0    1  2022       2
# 2022-01-23  391555.0    1  2022       3
# 2022-01-30  407864.0    1  2022       4
# ...              ...  ...   ...     ...
# 2023-03-05  381386.0    3  2023       9
# 2023-03-12  353466.0    3  2023      10
# 2023-03-19  411243.0    3  2023      11
# 2023-03-26  388934.0    3  2023      12
# 2023-04-02    7280.0    4  2023      13
#
# [66 rows x 4 columns]

# %%
train_frac = 0.8
n_train = int(train_frac * len(df))

train_df = df.iloc[:n_train]
test_df = df.iloc[n_train:]

# %%
X_columns = ['MES', 'ANO', 'SEMANA']
y_column = 'CANTIDAD'

X_train = train_df[X_columns].values
y_train = train_df[y_column].values

X_test = test_df[X_columns].values
y_test = test_df[y_column].values

# %%
from sklearn.preprocessing import StandardScaler

scaler_x = StandardScaler()
X_train_scaled = scaler_x.fit_transform(X_train)
X_test_scaled = scaler_x.transform(X_test)

scaler_y= StandardScaler()
Y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1,1))
y_test_scaled = scaler_y.transform(y_test.reshape(-1,1))


# Utiliza X_train_scaled y X_test_scaled al entrenar y evaluar la NNGP

# %%
def create_sliding_window_data(X, y, window_size):
    X_windowed = []
    y_windowed = []
    
    for i in range(len(X) - window_size):
        X_windowed.append(X[i:i + window_size])
        y_windowed.append(y[i + window_size])
        
    return np.array(X_windowed), np.array(y_windowed)

# %%
window_size = 4

X_train_windowed, y_train_windowed = create_sliding_window_data(X_train_scaled, Y_train_scaled, window_size)
X_test_windowed, y_test_windowed = create_sliding_window_data(X_test_scaled, y_test_scaled, window_size)

# %%
n_layers = 2
n_neurons = 50
activation_fn = tf.nn.relu
# kernel_fn = tfpm.nn.relu_kernel

nngp_model = tf.keras.Sequential()

for _ in range(n_layers):
    nngp_model.add(tf.keras.layers.TimeDistributed(tfpl.DenseReparameterization(
        input_shape=(window_size, 5),
        units=n_neurons,
        activation=tf.nn.softmax,
        kernel_prior_fn=tfpl.default_multivariate_normal_fn,
        kernel_posterior_fn=tfpl.default_mean_field_normal_fn())))

    nngp_model.add(tf.keras.layers.TimeDistributed(tfpl.DistributionLambda(
        lambda t: tfd.Normal(loc=t, scale=1.0))))

# Añade una capa LSTM o GRU si deseas incluir la estructura temporal
nngp_model.add(tf.keras.layers.LSTM(32))

nngp_model.add(tf.keras.layers.Dense(1))

# %%
# # Especifica la profundidad de la red y el número de neuronas por capa
# n_layers = 2
# n_neurons = 50

# # Crea la función de activación y el kernel de la NNGP
# activation_fn = tf.nn.relu
# # kernel_fn = tfpm.nn.relu_kernel

# # Construye el modelo NNGP
# nngp_model = tf.keras.Sequential()
# for _ in range(n_layers):
#     nngp_model.add(tfpl.DenseReparameterization(input_shape=(5,),
#                                                 units=n_neurons,
#                                                 activation=None,
#                                                 kernel_prior_fn=tfpl.default_multivariate_normal_fn,
#                                                 kernel_posterior_fn=tfpl.default_mean_field_normal_fn()))
#     nngp_model.add(tfpl.DistributionLambda(lambda t: tfd.Normal(loc=t, scale=1.0)))

# %%
# Compila y entrena el modelo
# nngp_model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.01),loss=lambda y, rv_y: -rv_y.log_prob(y))
nngp_model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.01),loss=tf.keras.losses.MeanSquaredError())
nngp_model.fit(X_train_windowed, y_train_windowed, epochs=800, verbose=2)
# Out:
# Epoch 1/800
# /home/bdebian/.virtualenvs/predeman/lib/python3.10/site-packages/tensorflow_probability/python/layers/util.py:95: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   loc = add_variable_fn(
# /home/bdebian/.virtualenvs/predeman/lib/python3.10/site-packages/tensorflow_probability/python/layers/util.py:105: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   untransformed_scale = add_variable_fn(
# 2/2 - 2s - loss: 6699.2759 - 2s/epoch - 794ms/step
# Epoch 2/800
# 2/2 - 0s - loss: 6644.0405 - 6ms/epoch - 3ms/step
# Epoch 3/800
# 2/2 - 0s - loss: 6589.7227 - 7ms/epoch - 3ms/step
# Epoch 4/800
# 2/2 - 0s - loss: 6536.3281 - 5ms/epoch - 3ms/step
# Epoch 5/800
# 2/2 - 0s - loss: 6483.4985 - 5ms/epoch - 3ms/step
# Epoch 6/800
# 2/2 - 0s - loss: 6431.3184 - 6ms/epoch - 3ms/step
# Epoch 7/800
# 2/2 - 0s - loss: 6379.1562 - 5ms/epoch - 3ms/step
# Epoch 8/800
# 2/2 - 0s - loss: 6327.3911 - 5ms/epoch - 2ms/step
# Epoch 9/800
# 2/2 - 0s - loss: 6275.8418 - 6ms/epoch - 3ms/step
# Epoch 10/800
# 2/2 - 0s - loss: 6224.3022 - 6ms/epoch - 3ms/step
# Epoch 11/800
# 2/2 - 0s - loss: 6172.8813 - 7ms/epoch - 4ms/step
# Epoch 12/800
# 2/2 - 0s - loss: 6121.6108 - 7ms/epoch - 3ms/step
# Epoch 13/800
# 2/2 - 0s - loss: 6070.4062 - 7ms/epoch - 4ms/step
# Epoch 14/800
# 2/2 - 0s - loss: 6019.2324 - 6ms/epoch - 3ms/step
# Epoch 15/800
# 2/2 - 0s - loss: 5968.1836 - 4ms/epoch - 2ms/step
# Epoch 16/800
# 2/2 - 0s - loss: 5917.1953 - 6ms/epoch - 3ms/step
# Epoch 17/800
# 2/2 - 0s - loss: 5866.1875 - 6ms/epoch - 3ms/step
# Epoch 18/800
# 2/2 - 0s - loss: 5815.2466 - 6ms/epoch - 3ms/step
# Epoch 19/800
# 2/2 - 0s - loss: 5764.4629 - 6ms/epoch - 3ms/step
# Epoch 20/800
# 2/2 - 0s - loss: 5713.6597 - 5ms/epoch - 3ms/step
# Epoch 21/800
# 2/2 - 0s - loss: 5663.0195 - 7ms/epoch - 3ms/step
# Epoch 22/800
# 2/2 - 0s - loss: 5612.3931 - 6ms/epoch - 3ms/step
# Epoch 23/800
# 2/2 - 0s - loss: 5561.7168 - 6ms/epoch - 3ms/step
# Epoch 24/800
# 2/2 - 0s - loss: 5511.2739 - 7ms/epoch - 4ms/step
# Epoch 25/800
# 2/2 - 0s - loss: 5460.8618 - 6ms/epoch - 3ms/step
# Epoch 26/800
# 2/2 - 0s - loss: 5410.4966 - 7ms/epoch - 3ms/step
# Epoch 27/800
# 2/2 - 0s - loss: 5360.1860 - 6ms/epoch - 3ms/step
# Epoch 28/800
# 2/2 - 0s - loss: 5310.0151 - 6ms/epoch - 3ms/step
# Epoch 29/800
# 2/2 - 0s - loss: 5259.8599 - 5ms/epoch - 3ms/step
# Epoch 30/800
# 2/2 - 0s - loss: 5209.9131 - 6ms/epoch - 3ms/step
# Epoch 31/800
# 2/2 - 0s - loss: 5159.8457 - 6ms/epoch - 3ms/step
# Epoch 32/800
# 2/2 - 0s - loss: 5110.0234 - 7ms/epoch - 3ms/step
# Epoch 33/800
# 2/2 - 0s - loss: 5060.2075 - 7ms/epoch - 4ms/step
# Epoch 34/800
# 2/2 - 0s - loss: 5010.4575 - 6ms/epoch - 3ms/step
# Epoch 35/800
# 2/2 - 0s - loss: 4960.8281 - 6ms/epoch - 3ms/step
# Epoch 36/800
# 2/2 - 0s - loss: 4911.3374 - 7ms/epoch - 3ms/step
# Epoch 37/800
# 2/2 - 0s - loss: 4861.8125 - 6ms/epoch - 3ms/step
# Epoch 38/800
# 2/2 - 0s - loss: 4812.5176 - 7ms/epoch - 4ms/step
# Epoch 39/800
# 2/2 - 0s - loss: 4763.3018 - 6ms/epoch - 3ms/step
# Epoch 40/800
# 2/2 - 0s - loss: 4714.1636 - 7ms/epoch - 4ms/step
# Epoch 41/800
# 2/2 - 0s - loss: 4665.0972 - 6ms/epoch - 3ms/step
# Epoch 42/800
# 2/2 - 0s - loss: 4616.1099 - 7ms/epoch - 3ms/step
# Epoch 43/800
# 2/2 - 0s - loss: 4567.3062 - 6ms/epoch - 3ms/step
# Epoch 44/800
# 2/2 - 0s - loss: 4518.5879 - 6ms/epoch - 3ms/step
# Epoch 45/800
# 2/2 - 0s - loss: 4469.9878 - 7ms/epoch - 3ms/step
# Epoch 46/800
# 2/2 - 0s - loss: 4421.4351 - 8ms/epoch - 4ms/step
# Epoch 47/800
# 2/2 - 0s - loss: 4373.0269 - 6ms/epoch - 3ms/step
# Epoch 48/800
# 2/2 - 0s - loss: 4324.7954 - 6ms/epoch - 3ms/step
# Epoch 49/800
# 2/2 - 0s - loss: 4276.6772 - 7ms/epoch - 3ms/step
# Epoch 50/800
# 2/2 - 0s - loss: 4228.6577 - 7ms/epoch - 3ms/step
# Epoch 51/800
# 2/2 - 0s - loss: 4180.7817 - 7ms/epoch - 3ms/step
# Epoch 52/800
# 2/2 - 0s - loss: 4132.9038 - 6ms/epoch - 3ms/step
# Epoch 53/800
# 2/2 - 0s - loss: 4085.2676 - 6ms/epoch - 3ms/step
# Epoch 54/800
# 2/2 - 0s - loss: 4037.7947 - 6ms/epoch - 3ms/step
# Epoch 55/800
# 2/2 - 0s - loss: 3990.4612 - 6ms/epoch - 3ms/step
# Epoch 56/800
# 2/2 - 0s - loss: 3943.1692 - 5ms/epoch - 3ms/step
# Epoch 57/800
# 2/2 - 0s - loss: 3896.0959 - 6ms/epoch - 3ms/step
# Epoch 58/800
# 2/2 - 0s - loss: 3849.1497 - 7ms/epoch - 4ms/step
# Epoch 59/800
# 2/2 - 0s - loss: 3802.3430 - 6ms/epoch - 3ms/step
# Epoch 60/800
# 2/2 - 0s - loss: 3755.7405 - 5ms/epoch - 3ms/step
# Epoch 61/800
# 2/2 - 0s - loss: 3709.2043 - 5ms/epoch - 3ms/step
# Epoch 62/800
# 2/2 - 0s - loss: 3662.9082 - 5ms/epoch - 3ms/step
# Epoch 63/800
# 2/2 - 0s - loss: 3616.7200 - 7ms/epoch - 3ms/step
# Epoch 64/800
# 2/2 - 0s - loss: 3570.7019 - 8ms/epoch - 4ms/step
# Epoch 65/800
# 2/2 - 0s - loss: 3524.8877 - 6ms/epoch - 3ms/step
# Epoch 66/800
# 2/2 - 0s - loss: 3479.2551 - 6ms/epoch - 3ms/step
# Epoch 67/800
# 2/2 - 0s - loss: 3433.7683 - 6ms/epoch - 3ms/step
# Epoch 68/800
# 2/2 - 0s - loss: 3388.4226 - 6ms/epoch - 3ms/step
# Epoch 69/800
# 2/2 - 0s - loss: 3343.3054 - 7ms/epoch - 3ms/step
# Epoch 70/800
# 2/2 - 0s - loss: 3298.3674 - 6ms/epoch - 3ms/step
# Epoch 71/800
# 2/2 - 0s - loss: 3253.5974 - 6ms/epoch - 3ms/step
# Epoch 72/800
# 2/2 - 0s - loss: 3209.0452 - 5ms/epoch - 2ms/step
# Epoch 73/800
# 2/2 - 0s - loss: 3164.6692 - 5ms/epoch - 2ms/step
# Epoch 74/800
# 2/2 - 0s - loss: 3120.5349 - 4ms/epoch - 2ms/step
# Epoch 75/800
# 2/2 - 0s - loss: 3076.5547 - 4ms/epoch - 2ms/step
# Epoch 76/800
# 2/2 - 0s - loss: 3032.8118 - 5ms/epoch - 3ms/step
# Epoch 77/800
# 2/2 - 0s - loss: 2989.2205 - 7ms/epoch - 4ms/step
# Epoch 78/800
# 2/2 - 0s - loss: 2945.9617 - 6ms/epoch - 3ms/step
# Epoch 79/800
# 2/2 - 0s - loss: 2902.8723 - 6ms/epoch - 3ms/step
# Epoch 80/800
# 2/2 - 0s - loss: 2859.9587 - 5ms/epoch - 2ms/step
# Epoch 81/800
# 2/2 - 0s - loss: 2817.2717 - 5ms/epoch - 2ms/step
# Epoch 82/800
# 2/2 - 0s - loss: 2774.8887 - 4ms/epoch - 2ms/step
# Epoch 83/800
# 2/2 - 0s - loss: 2732.7356 - 6ms/epoch - 3ms/step
# Epoch 84/800
# 2/2 - 0s - loss: 2690.7686 - 7ms/epoch - 3ms/step
# Epoch 85/800
# 2/2 - 0s - loss: 2649.0120 - 5ms/epoch - 2ms/step
# Epoch 86/800
# 2/2 - 0s - loss: 2607.5908 - 6ms/epoch - 3ms/step
# Epoch 87/800
# 2/2 - 0s - loss: 2566.3833 - 5ms/epoch - 3ms/step
# Epoch 88/800
# 2/2 - 0s - loss: 2525.4626 - 6ms/epoch - 3ms/step
# Epoch 89/800
# 2/2 - 0s - loss: 2484.7571 - 6ms/epoch - 3ms/step
# Epoch 90/800
# 2/2 - 0s - loss: 2444.2969 - 5ms/epoch - 2ms/step
# Epoch 91/800
# 2/2 - 0s - loss: 2404.1521 - 7ms/epoch - 3ms/step
# Epoch 92/800
# 2/2 - 0s - loss: 2364.2568 - 6ms/epoch - 3ms/step
# Epoch 93/800
# 2/2 - 0s - loss: 2324.6616 - 6ms/epoch - 3ms/step
# Epoch 94/800
# 2/2 - 0s - loss: 2285.3389 - 8ms/epoch - 4ms/step
# Epoch 95/800
# 2/2 - 0s - loss: 2246.2844 - 6ms/epoch - 3ms/step
# Epoch 96/800
# 2/2 - 0s - loss: 2207.4910 - 6ms/epoch - 3ms/step
# Epoch 97/800
# 2/2 - 0s - loss: 2169.0562 - 5ms/epoch - 3ms/step
# Epoch 98/800
# 2/2 - 0s - loss: 2130.8972 - 4ms/epoch - 2ms/step
# Epoch 99/800
# 2/2 - 0s - loss: 2092.9871 - 7ms/epoch - 3ms/step
# Epoch 100/800
# 2/2 - 0s - loss: 2055.4797 - 6ms/epoch - 3ms/step
# Epoch 101/800
# 2/2 - 0s - loss: 2018.1782 - 8ms/epoch - 4ms/step
# Epoch 102/800
# 2/2 - 0s - loss: 1981.2841 - 6ms/epoch - 3ms/step
# Epoch 103/800
# 2/2 - 0s - loss: 1944.6654 - 6ms/epoch - 3ms/step
# Epoch 104/800
# 2/2 - 0s - loss: 1908.3580 - 5ms/epoch - 2ms/step
# Epoch 105/800
# 2/2 - 0s - loss: 1872.3817 - 6ms/epoch - 3ms/step
# Epoch 106/800
# 2/2 - 0s - loss: 1836.7516 - 6ms/epoch - 3ms/step
# Epoch 107/800
# 2/2 - 0s - loss: 1801.3993 - 5ms/epoch - 2ms/step
# Epoch 108/800
# 2/2 - 0s - loss: 1766.4393 - 5ms/epoch - 3ms/step
# Epoch 109/800
# 2/2 - 0s - loss: 1731.7812 - 7ms/epoch - 3ms/step
# Epoch 110/800
# 2/2 - 0s - loss: 1697.5287 - 6ms/epoch - 3ms/step
# Epoch 111/800
# 2/2 - 0s - loss: 1663.5397 - 5ms/epoch - 3ms/step
# Epoch 112/800
# 2/2 - 0s - loss: 1629.9530 - 5ms/epoch - 3ms/step
# Epoch 113/800
# 2/2 - 0s - loss: 1596.7616 - 6ms/epoch - 3ms/step
# Epoch 114/800
# 2/2 - 0s - loss: 1563.8717 - 6ms/epoch - 3ms/step
# Epoch 115/800
# 2/2 - 0s - loss: 1531.3052 - 6ms/epoch - 3ms/step
# Epoch 116/800
# 2/2 - 0s - loss: 1499.1647 - 6ms/epoch - 3ms/step
# Epoch 117/800
# 2/2 - 0s - loss: 1467.3646 - 6ms/epoch - 3ms/step
# Epoch 118/800
# 2/2 - 0s - loss: 1435.9331 - 5ms/epoch - 2ms/step
# Epoch 119/800
# 2/2 - 0s - loss: 1404.8822 - 7ms/epoch - 3ms/step
# Epoch 120/800
# 2/2 - 0s - loss: 1374.2109 - 5ms/epoch - 3ms/step
# Epoch 121/800
# 2/2 - 0s - loss: 1343.8954 - 6ms/epoch - 3ms/step
# Epoch 122/800
# 2/2 - 0s - loss: 1313.9889 - 6ms/epoch - 3ms/step
# Epoch 123/800
# 2/2 - 0s - loss: 1284.4598 - 8ms/epoch - 4ms/step
# Epoch 124/800
# 2/2 - 0s - loss: 1255.2765 - 5ms/epoch - 2ms/step
# Epoch 125/800
# 2/2 - 0s - loss: 1226.5131 - 6ms/epoch - 3ms/step
# Epoch 126/800
# 2/2 - 0s - loss: 1198.1254 - 8ms/epoch - 4ms/step
# Epoch 127/800
# 2/2 - 0s - loss: 1170.1433 - 7ms/epoch - 3ms/step
# Epoch 128/800
# 2/2 - 0s - loss: 1142.5693 - 6ms/epoch - 3ms/step
# Epoch 129/800
# 2/2 - 0s - loss: 1115.3434 - 5ms/epoch - 3ms/step
# Epoch 130/800
# 2/2 - 0s - loss: 1088.5267 - 5ms/epoch - 3ms/step
# Epoch 131/800
# 2/2 - 0s - loss: 1062.1007 - 6ms/epoch - 3ms/step
# Epoch 132/800
# 2/2 - 0s - loss: 1036.0597 - 6ms/epoch - 3ms/step
# Epoch 133/800
# 2/2 - 0s - loss: 1010.4697 - 7ms/epoch - 3ms/step
# Epoch 134/800
# 2/2 - 0s - loss: 985.2636 - 5ms/epoch - 3ms/step
# Epoch 135/800
# 2/2 - 0s - loss: 960.4053 - 5ms/epoch - 3ms/step
# Epoch 136/800
# 2/2 - 0s - loss: 935.9849 - 7ms/epoch - 3ms/step
# Epoch 137/800
# 2/2 - 0s - loss: 912.0029 - 4ms/epoch - 2ms/step
# Epoch 138/800
# 2/2 - 0s - loss: 888.3400 - 7ms/epoch - 3ms/step
# Epoch 139/800
# 2/2 - 0s - loss: 865.1717 - 6ms/epoch - 3ms/step
# Epoch 140/800
# 2/2 - 0s - loss: 842.2745 - 6ms/epoch - 3ms/step
# Epoch 141/800
# 2/2 - 0s - loss: 819.8965 - 7ms/epoch - 3ms/step
# Epoch 142/800
# 2/2 - 0s - loss: 797.8483 - 7ms/epoch - 3ms/step
# Epoch 143/800
# 2/2 - 0s - loss: 776.2263 - 6ms/epoch - 3ms/step
# Epoch 144/800
# 2/2 - 0s - loss: 754.9863 - 6ms/epoch - 3ms/step
# Epoch 145/800
# 2/2 - 0s - loss: 734.1208 - 7ms/epoch - 3ms/step
# Epoch 146/800
# 2/2 - 0s - loss: 713.7098 - 6ms/epoch - 3ms/step
# Epoch 147/800
# 2/2 - 0s - loss: 693.6340 - 7ms/epoch - 4ms/step
# Epoch 148/800
# 2/2 - 0s - loss: 673.9611 - 4ms/epoch - 2ms/step
# Epoch 149/800
# 2/2 - 0s - loss: 654.7182 - 7ms/epoch - 4ms/step
# Epoch 150/800
# 2/2 - 0s - loss: 635.8214 - 6ms/epoch - 3ms/step
# Epoch 151/800
# 2/2 - 0s - loss: 617.2854 - 7ms/epoch - 3ms/step
# Epoch 152/800
# 2/2 - 0s - loss: 599.1537 - 6ms/epoch - 3ms/step
# Epoch 153/800
# 2/2 - 0s - loss: 581.4377 - 7ms/epoch - 3ms/step
# Epoch 154/800
# 2/2 - 0s - loss: 564.0474 - 5ms/epoch - 2ms/step
# Epoch 155/800
# 2/2 - 0s - loss: 547.0671 - 4ms/epoch - 2ms/step
# Epoch 156/800
# 2/2 - 0s - loss: 530.4448 - 8ms/epoch - 4ms/step
# Epoch 157/800
# 2/2 - 0s - loss: 514.2402 - 7ms/epoch - 4ms/step
# Epoch 158/800
# 2/2 - 0s - loss: 498.3721 - 7ms/epoch - 4ms/step
# Epoch 159/800
# 2/2 - 0s - loss: 482.8206 - 7ms/epoch - 3ms/step
# Epoch 160/800
# 2/2 - 0s - loss: 467.6494 - 6ms/epoch - 3ms/step
# Epoch 161/800
# 2/2 - 0s - loss: 452.8454 - 6ms/epoch - 3ms/step
# Epoch 162/800
# 2/2 - 0s - loss: 438.3979 - 5ms/epoch - 3ms/step
# Epoch 163/800
# 2/2 - 0s - loss: 424.2975 - 6ms/epoch - 3ms/step
# Epoch 164/800
# 2/2 - 0s - loss: 410.5815 - 6ms/epoch - 3ms/step
# Epoch 165/800
# 2/2 - 0s - loss: 397.1262 - 6ms/epoch - 3ms/step
# Epoch 166/800
# 2/2 - 0s - loss: 384.0367 - 6ms/epoch - 3ms/step
# Epoch 167/800
# 2/2 - 0s - loss: 371.2926 - 6ms/epoch - 3ms/step
# Epoch 168/800
# 2/2 - 0s - loss: 358.8642 - 7ms/epoch - 3ms/step
# Epoch 169/800
# 2/2 - 0s - loss: 346.7708 - 6ms/epoch - 3ms/step
# Epoch 170/800
# 2/2 - 0s - loss: 334.9792 - 8ms/epoch - 4ms/step
# Epoch 171/800
# 2/2 - 0s - loss: 323.4939 - 7ms/epoch - 3ms/step
# Epoch 172/800
# 2/2 - 0s - loss: 312.3570 - 6ms/epoch - 3ms/step
# Epoch 173/800
# 2/2 - 0s - loss: 301.5046 - 7ms/epoch - 4ms/step
# Epoch 174/800
# 2/2 - 0s - loss: 290.9305 - 7ms/epoch - 3ms/step
# Epoch 175/800
# 2/2 - 0s - loss: 280.6267 - 6ms/epoch - 3ms/step
# Epoch 176/800
# 2/2 - 0s - loss: 270.6634 - 6ms/epoch - 3ms/step
# Epoch 177/800
# 2/2 - 0s - loss: 261.0120 - 6ms/epoch - 3ms/step
# Epoch 178/800
# 2/2 - 0s - loss: 251.5869 - 7ms/epoch - 4ms/step
# Epoch 179/800
# 2/2 - 0s - loss: 242.4533 - 6ms/epoch - 3ms/step
# Epoch 180/800
# 2/2 - 0s - loss: 233.5923 - 6ms/epoch - 3ms/step
# Epoch 181/800
# 2/2 - 0s - loss: 225.0087 - 7ms/epoch - 3ms/step
# Epoch 182/800
# 2/2 - 0s - loss: 216.6349 - 6ms/epoch - 3ms/step
# Epoch 183/800
# 2/2 - 0s - loss: 208.5374 - 8ms/epoch - 4ms/step
# Epoch 184/800
# 2/2 - 0s - loss: 200.6781 - 5ms/epoch - 2ms/step
# Epoch 185/800
# 2/2 - 0s - loss: 193.1109 - 5ms/epoch - 3ms/step
# Epoch 186/800
# 2/2 - 0s - loss: 185.7851 - 6ms/epoch - 3ms/step
# Epoch 187/800
# 2/2 - 0s - loss: 178.6232 - 7ms/epoch - 3ms/step
# Epoch 188/800
# 2/2 - 0s - loss: 171.7729 - 7ms/epoch - 3ms/step
# Epoch 189/800
# 2/2 - 0s - loss: 165.0811 - 7ms/epoch - 3ms/step
# Epoch 190/800
# 2/2 - 0s - loss: 158.6189 - 7ms/epoch - 4ms/step
# Epoch 191/800
# 2/2 - 0s - loss: 152.3813 - 6ms/epoch - 3ms/step
# Epoch 192/800
# 2/2 - 0s - loss: 146.3453 - 6ms/epoch - 3ms/step
# Epoch 193/800
# 2/2 - 0s - loss: 140.4873 - 6ms/epoch - 3ms/step
# Epoch 194/800
# 2/2 - 0s - loss: 134.8535 - 6ms/epoch - 3ms/step
# Epoch 195/800
# 2/2 - 0s - loss: 129.4250 - 7ms/epoch - 3ms/step
# Epoch 196/800
# 2/2 - 0s - loss: 124.1978 - 6ms/epoch - 3ms/step
# Epoch 197/800
# 2/2 - 0s - loss: 119.0807 - 6ms/epoch - 3ms/step
# Epoch 198/800
# 2/2 - 0s - loss: 114.2068 - 6ms/epoch - 3ms/step
# Epoch 199/800
# 2/2 - 0s - loss: 109.5090 - 5ms/epoch - 3ms/step
# Epoch 200/800
# 2/2 - 0s - loss: 104.9077 - 5ms/epoch - 2ms/step
# Epoch 201/800
# 2/2 - 0s - loss: 100.5693 - 7ms/epoch - 3ms/step
# Epoch 202/800
# 2/2 - 0s - loss: 96.3180 - 8ms/epoch - 4ms/step
# Epoch 203/800
# 2/2 - 0s - loss: 92.2778 - 6ms/epoch - 3ms/step
# Epoch 204/800
# 2/2 - 0s - loss: 88.3539 - 6ms/epoch - 3ms/step
# Epoch 205/800
# 2/2 - 0s - loss: 84.5986 - 7ms/epoch - 3ms/step
# Epoch 206/800
# 2/2 - 0s - loss: 80.9724 - 6ms/epoch - 3ms/step
# Epoch 207/800
# 2/2 - 0s - loss: 77.4618 - 6ms/epoch - 3ms/step
# Epoch 208/800
# 2/2 - 0s - loss: 74.0965 - 6ms/epoch - 3ms/step
# Epoch 209/800
# 2/2 - 0s - loss: 70.8048 - 7ms/epoch - 3ms/step
# Epoch 210/800
# 2/2 - 0s - loss: 67.7593 - 7ms/epoch - 3ms/step
# Epoch 211/800
# 2/2 - 0s - loss: 64.7676 - 6ms/epoch - 3ms/step
# Epoch 212/800
# 2/2 - 0s - loss: 61.8805 - 6ms/epoch - 3ms/step
# Epoch 213/800
# 2/2 - 0s - loss: 59.1270 - 6ms/epoch - 3ms/step
# Epoch 214/800
# 2/2 - 0s - loss: 56.5039 - 5ms/epoch - 2ms/step
# Epoch 215/800
# 2/2 - 0s - loss: 53.9450 - 8ms/epoch - 4ms/step
# Epoch 216/800
# 2/2 - 0s - loss: 51.5202 - 7ms/epoch - 4ms/step
# Epoch 217/800
# 2/2 - 0s - loss: 49.1662 - 7ms/epoch - 3ms/step
# Epoch 218/800
# 2/2 - 0s - loss: 46.9446 - 7ms/epoch - 3ms/step
# Epoch 219/800
# 2/2 - 0s - loss: 44.7908 - 7ms/epoch - 3ms/step
# Epoch 220/800
# 2/2 - 0s - loss: 42.7492 - 6ms/epoch - 3ms/step
# Epoch 221/800
# 2/2 - 0s - loss: 40.7670 - 6ms/epoch - 3ms/step
# Epoch 222/800
# 2/2 - 0s - loss: 38.8649 - 6ms/epoch - 3ms/step
# Epoch 223/800
# 2/2 - 0s - loss: 37.0683 - 6ms/epoch - 3ms/step
# Epoch 224/800
# 2/2 - 0s - loss: 35.3537 - 5ms/epoch - 3ms/step
# Epoch 225/800
# 2/2 - 0s - loss: 33.6850 - 5ms/epoch - 3ms/step
# Epoch 226/800
# 2/2 - 0s - loss: 32.1185 - 6ms/epoch - 3ms/step
# Epoch 227/800
# 2/2 - 0s - loss: 30.5985 - 5ms/epoch - 2ms/step
# Epoch 228/800
# 2/2 - 0s - loss: 29.1528 - 4ms/epoch - 2ms/step
# Epoch 229/800
# 2/2 - 0s - loss: 27.7414 - 5ms/epoch - 3ms/step
# Epoch 230/800
# 2/2 - 0s - loss: 26.4438 - 7ms/epoch - 4ms/step
# Epoch 231/800
# 2/2 - 0s - loss: 25.1938 - 6ms/epoch - 3ms/step
# Epoch 232/800
# 2/2 - 0s - loss: 23.9564 - 8ms/epoch - 4ms/step
# Epoch 233/800
# 2/2 - 0s - loss: 22.8114 - 6ms/epoch - 3ms/step
# Epoch 234/800
# 2/2 - 0s - loss: 21.7123 - 6ms/epoch - 3ms/step
# Epoch 235/800
# 2/2 - 0s - loss: 20.6821 - 7ms/epoch - 3ms/step
# Epoch 236/800
# 2/2 - 0s - loss: 19.6627 - 5ms/epoch - 3ms/step
# Epoch 237/800
# 2/2 - 0s - loss: 18.7292 - 5ms/epoch - 3ms/step
# Epoch 238/800
# 2/2 - 0s - loss: 17.7888 - 6ms/epoch - 3ms/step
# Epoch 239/800
# 2/2 - 0s - loss: 16.9233 - 6ms/epoch - 3ms/step
# Epoch 240/800
# 2/2 - 0s - loss: 16.1152 - 8ms/epoch - 4ms/step
# Epoch 241/800
# 2/2 - 0s - loss: 15.3337 - 8ms/epoch - 4ms/step
# Epoch 242/800
# 2/2 - 0s - loss: 14.5638 - 7ms/epoch - 3ms/step
# Epoch 243/800
# 2/2 - 0s - loss: 13.8623 - 7ms/epoch - 3ms/step
# Epoch 244/800
# 2/2 - 0s - loss: 13.1795 - 7ms/epoch - 4ms/step
# Epoch 245/800
# 2/2 - 0s - loss: 12.5113 - 7ms/epoch - 3ms/step
# Epoch 246/800
# 2/2 - 0s - loss: 11.8991 - 5ms/epoch - 2ms/step
# Epoch 247/800
# 2/2 - 0s - loss: 11.3139 - 4ms/epoch - 2ms/step
# Epoch 248/800
# 2/2 - 0s - loss: 10.7787 - 6ms/epoch - 3ms/step
# Epoch 249/800
# 2/2 - 0s - loss: 10.2179 - 7ms/epoch - 3ms/step
# Epoch 250/800
# 2/2 - 0s - loss: 9.7281 - 5ms/epoch - 2ms/step
# Epoch 251/800
# 2/2 - 0s - loss: 9.2437 - 7ms/epoch - 4ms/step
# Epoch 252/800
# 2/2 - 0s - loss: 8.7949 - 6ms/epoch - 3ms/step
# Epoch 253/800
# 2/2 - 0s - loss: 8.3616 - 6ms/epoch - 3ms/step
# Epoch 254/800
# 2/2 - 0s - loss: 7.9427 - 6ms/epoch - 3ms/step
# Epoch 255/800
# 2/2 - 0s - loss: 7.5775 - 7ms/epoch - 4ms/step
# Epoch 256/800
# 2/2 - 0s - loss: 7.2181 - 6ms/epoch - 3ms/step
# Epoch 257/800
# 2/2 - 0s - loss: 6.8535 - 5ms/epoch - 3ms/step
# Epoch 258/800
# 2/2 - 0s - loss: 6.5150 - 6ms/epoch - 3ms/step
# Epoch 259/800
# 2/2 - 0s - loss: 6.1795 - 7ms/epoch - 3ms/step
# Epoch 260/800
# 2/2 - 0s - loss: 5.9080 - 7ms/epoch - 4ms/step
# Epoch 261/800
# 2/2 - 0s - loss: 5.5832 - 7ms/epoch - 4ms/step
# Epoch 262/800
# 2/2 - 0s - loss: 5.3483 - 7ms/epoch - 3ms/step
# Epoch 263/800
# 2/2 - 0s - loss: 5.0950 - 7ms/epoch - 3ms/step
# Epoch 264/800
# 2/2 - 0s - loss: 4.8744 - 8ms/epoch - 4ms/step
# Epoch 265/800
# 2/2 - 0s - loss: 4.6055 - 7ms/epoch - 4ms/step
# Epoch 266/800
# 2/2 - 0s - loss: 4.4178 - 7ms/epoch - 4ms/step
# Epoch 267/800
# 2/2 - 0s - loss: 4.1962 - 7ms/epoch - 4ms/step
# Epoch 268/800
# 2/2 - 0s - loss: 4.0223 - 7ms/epoch - 3ms/step
# Epoch 269/800
# 2/2 - 0s - loss: 3.8260 - 5ms/epoch - 3ms/step
# Epoch 270/800
# 2/2 - 0s - loss: 3.6473 - 7ms/epoch - 3ms/step
# Epoch 271/800
# 2/2 - 0s - loss: 3.4572 - 6ms/epoch - 3ms/step
# Epoch 272/800
# 2/2 - 0s - loss: 3.3219 - 6ms/epoch - 3ms/step
# Epoch 273/800
# 2/2 - 0s - loss: 3.2073 - 7ms/epoch - 3ms/step
# Epoch 274/800
# 2/2 - 0s - loss: 3.0585 - 6ms/epoch - 3ms/step
# Epoch 275/800
# 2/2 - 0s - loss: 2.9108 - 6ms/epoch - 3ms/step
# Epoch 276/800
# 2/2 - 0s - loss: 2.7762 - 6ms/epoch - 3ms/step
# Epoch 277/800
# 2/2 - 0s - loss: 2.6643 - 6ms/epoch - 3ms/step
# Epoch 278/800
# 2/2 - 0s - loss: 2.5681 - 6ms/epoch - 3ms/step
# Epoch 279/800
# 2/2 - 0s - loss: 2.4594 - 6ms/epoch - 3ms/step
# Epoch 280/800
# 2/2 - 0s - loss: 2.3589 - 5ms/epoch - 3ms/step
# Epoch 281/800
# 2/2 - 0s - loss: 2.2505 - 7ms/epoch - 4ms/step
# Epoch 282/800
# 2/2 - 0s - loss: 2.1879 - 6ms/epoch - 3ms/step
# Epoch 283/800
# 2/2 - 0s - loss: 2.0854 - 7ms/epoch - 3ms/step
# Epoch 284/800
# 2/2 - 0s - loss: 1.9994 - 7ms/epoch - 3ms/step
# Epoch 285/800
# 2/2 - 0s - loss: 1.9600 - 8ms/epoch - 4ms/step
# Epoch 286/800
# 2/2 - 0s - loss: 1.8855 - 7ms/epoch - 3ms/step
# Epoch 287/800
# 2/2 - 0s - loss: 1.8282 - 8ms/epoch - 4ms/step
# Epoch 288/800
# 2/2 - 0s - loss: 1.7459 - 7ms/epoch - 4ms/step
# Epoch 289/800
# 2/2 - 0s - loss: 1.6769 - 6ms/epoch - 3ms/step
# Epoch 290/800
# 2/2 - 0s - loss: 1.6075 - 7ms/epoch - 4ms/step
# Epoch 291/800
# 2/2 - 0s - loss: 1.5952 - 8ms/epoch - 4ms/step
# Epoch 292/800
# 2/2 - 0s - loss: 1.5604 - 8ms/epoch - 4ms/step
# Epoch 293/800
# 2/2 - 0s - loss: 1.4964 - 7ms/epoch - 3ms/step
# Epoch 294/800
# 2/2 - 0s - loss: 1.4619 - 6ms/epoch - 3ms/step
# Epoch 295/800
# 2/2 - 0s - loss: 1.4531 - 5ms/epoch - 3ms/step
# Epoch 296/800
# 2/2 - 0s - loss: 1.4055 - 7ms/epoch - 3ms/step
# Epoch 297/800
# 2/2 - 0s - loss: 1.3268 - 7ms/epoch - 4ms/step
# Epoch 298/800
# 2/2 - 0s - loss: 1.2929 - 7ms/epoch - 4ms/step
# Epoch 299/800
# 2/2 - 0s - loss: 1.2806 - 6ms/epoch - 3ms/step
# Epoch 300/800
# 2/2 - 0s - loss: 1.2177 - 8ms/epoch - 4ms/step
# Epoch 301/800
# 2/2 - 0s - loss: 1.2179 - 7ms/epoch - 3ms/step
# Epoch 302/800
# 2/2 - 0s - loss: 1.1855 - 5ms/epoch - 3ms/step
# Epoch 303/800
# 2/2 - 0s - loss: 1.1716 - 6ms/epoch - 3ms/step
# Epoch 304/800
# 2/2 - 0s - loss: 1.1405 - 6ms/epoch - 3ms/step
# Epoch 305/800
# 2/2 - 0s - loss: 1.1194 - 8ms/epoch - 4ms/step
# Epoch 306/800
# 2/2 - 0s - loss: 1.1073 - 8ms/epoch - 4ms/step
# Epoch 307/800
# 2/2 - 0s - loss: 1.0911 - 8ms/epoch - 4ms/step
# Epoch 308/800
# 2/2 - 0s - loss: 1.1051 - 8ms/epoch - 4ms/step
# Epoch 309/800
# 2/2 - 0s - loss: 1.0406 - 8ms/epoch - 4ms/step
# Epoch 310/800
# 2/2 - 0s - loss: 1.0294 - 9ms/epoch - 4ms/step
# Epoch 311/800
# 2/2 - 0s - loss: 1.0202 - 7ms/epoch - 4ms/step
# Epoch 312/800
# 2/2 - 0s - loss: 1.0148 - 8ms/epoch - 4ms/step
# Epoch 313/800
# 2/2 - 0s - loss: 0.9979 - 6ms/epoch - 3ms/step
# Epoch 314/800
# 2/2 - 0s - loss: 0.9898 - 7ms/epoch - 3ms/step
# Epoch 315/800
# 2/2 - 0s - loss: 0.9868 - 5ms/epoch - 3ms/step
# Epoch 316/800
# 2/2 - 0s - loss: 0.9685 - 5ms/epoch - 3ms/step
# Epoch 317/800
# 2/2 - 0s - loss: 0.9308 - 7ms/epoch - 3ms/step
# Epoch 318/800
# 2/2 - 0s - loss: 0.9246 - 5ms/epoch - 3ms/step
# Epoch 319/800
# 2/2 - 0s - loss: 0.9233 - 6ms/epoch - 3ms/step
# Epoch 320/800
# 2/2 - 0s - loss: 0.9182 - 7ms/epoch - 3ms/step
# Epoch 321/800
# 2/2 - 0s - loss: 0.9279 - 8ms/epoch - 4ms/step
# Epoch 322/800
# 2/2 - 0s - loss: 0.8954 - 7ms/epoch - 4ms/step
# Epoch 323/800
# 2/2 - 0s - loss: 0.9128 - 7ms/epoch - 3ms/step
# Epoch 324/800
# 2/2 - 0s - loss: 0.8899 - 6ms/epoch - 3ms/step
# Epoch 325/800
# 2/2 - 0s - loss: 0.8896 - 6ms/epoch - 3ms/step
# Epoch 326/800
# 2/2 - 0s - loss: 0.8593 - 6ms/epoch - 3ms/step
# Epoch 327/800
# 2/2 - 0s - loss: 0.8530 - 5ms/epoch - 3ms/step
# Epoch 328/800
# 2/2 - 0s - loss: 0.8695 - 4ms/epoch - 2ms/step
# Epoch 329/800
# 2/2 - 0s - loss: 0.8336 - 7ms/epoch - 3ms/step
# Epoch 330/800
# 2/2 - 0s - loss: 0.8538 - 5ms/epoch - 2ms/step
# Epoch 331/800
# 2/2 - 0s - loss: 0.8604 - 6ms/epoch - 3ms/step
# Epoch 332/800
# 2/2 - 0s - loss: 0.8454 - 5ms/epoch - 3ms/step
# Epoch 333/800
# 2/2 - 0s - loss: 0.8227 - 6ms/epoch - 3ms/step
# Epoch 334/800
# 2/2 - 0s - loss: 0.8356 - 23ms/epoch - 11ms/step
# Epoch 335/800
# 2/2 - 0s - loss: 0.8677 - 16ms/epoch - 8ms/step
# Epoch 336/800
# 2/2 - 0s - loss: 0.8448 - 13ms/epoch - 7ms/step
# Epoch 337/800
# 2/2 - 0s - loss: 0.8493 - 12ms/epoch - 6ms/step
# Epoch 338/800
# 2/2 - 0s - loss: 0.8518 - 9ms/epoch - 5ms/step
# Epoch 339/800
# 2/2 - 0s - loss: 0.8122 - 7ms/epoch - 3ms/step
# Epoch 340/800
# 2/2 - 0s - loss: 0.8384 - 6ms/epoch - 3ms/step
# Epoch 341/800
# 2/2 - 0s - loss: 0.8390 - 6ms/epoch - 3ms/step
# Epoch 342/800
# 2/2 - 0s - loss: 0.8034 - 7ms/epoch - 4ms/step
# Epoch 343/800
# 2/2 - 0s - loss: 0.8205 - 8ms/epoch - 4ms/step
# Epoch 344/800
# 2/2 - 0s - loss: 0.8527 - 8ms/epoch - 4ms/step
# Epoch 345/800
# 2/2 - 0s - loss: 0.8130 - 7ms/epoch - 3ms/step
# Epoch 346/800
# 2/2 - 0s - loss: 0.8518 - 8ms/epoch - 4ms/step
# Epoch 347/800
# 2/2 - 0s - loss: 0.8163 - 7ms/epoch - 3ms/step
# Epoch 348/800
# 2/2 - 0s - loss: 0.8129 - 6ms/epoch - 3ms/step
# Epoch 349/800
# 2/2 - 0s - loss: 0.8049 - 9ms/epoch - 4ms/step
# Epoch 350/800
# 2/2 - 0s - loss: 0.7940 - 7ms/epoch - 4ms/step
# Epoch 351/800
# 2/2 - 0s - loss: 0.8580 - 6ms/epoch - 3ms/step
# Epoch 352/800
# 2/2 - 0s - loss: 0.8048 - 6ms/epoch - 3ms/step
# Epoch 353/800
# 2/2 - 0s - loss: 0.8210 - 6ms/epoch - 3ms/step
# Epoch 354/800
# 2/2 - 0s - loss: 0.7868 - 5ms/epoch - 3ms/step
# Epoch 355/800
# 2/2 - 0s - loss: 0.7900 - 8ms/epoch - 4ms/step
# Epoch 356/800
# 2/2 - 0s - loss: 0.8051 - 8ms/epoch - 4ms/step
# Epoch 357/800
# 2/2 - 0s - loss: 0.7942 - 6ms/epoch - 3ms/step
# Epoch 358/800
# 2/2 - 0s - loss: 0.8114 - 5ms/epoch - 3ms/step
# Epoch 359/800
# 2/2 - 0s - loss: 0.8084 - 6ms/epoch - 3ms/step
# Epoch 360/800
# 2/2 - 0s - loss: 0.7795 - 7ms/epoch - 4ms/step
# Epoch 361/800
# 2/2 - 0s - loss: 0.8412 - 7ms/epoch - 3ms/step
# Epoch 362/800
# 2/2 - 0s - loss: 0.8273 - 8ms/epoch - 4ms/step
# Epoch 363/800
# 2/2 - 0s - loss: 0.7949 - 8ms/epoch - 4ms/step
# Epoch 364/800
# 2/2 - 0s - loss: 0.7998 - 6ms/epoch - 3ms/step
# Epoch 365/800
# 2/2 - 0s - loss: 0.8455 - 7ms/epoch - 3ms/step
# Epoch 366/800
# 2/2 - 0s - loss: 0.8286 - 7ms/epoch - 3ms/step
# Epoch 367/800
# 2/2 - 0s - loss: 0.8361 - 7ms/epoch - 3ms/step
# Epoch 368/800
# 2/2 - 0s - loss: 0.8189 - 7ms/epoch - 3ms/step
# Epoch 369/800
# 2/2 - 0s - loss: 0.7902 - 7ms/epoch - 3ms/step
# Epoch 370/800
# 2/2 - 0s - loss: 0.8131 - 6ms/epoch - 3ms/step
# Epoch 371/800
# 2/2 - 0s - loss: 0.8253 - 5ms/epoch - 3ms/step
# Epoch 372/800
# 2/2 - 0s - loss: 0.8033 - 7ms/epoch - 4ms/step
# Epoch 373/800
# 2/2 - 0s - loss: 0.7900 - 6ms/epoch - 3ms/step
# Epoch 374/800
# 2/2 - 0s - loss: 0.7923 - 7ms/epoch - 4ms/step
# Epoch 375/800
# 2/2 - 0s - loss: 0.8226 - 9ms/epoch - 4ms/step
# Epoch 376/800
# 2/2 - 0s - loss: 0.8231 - 9ms/epoch - 4ms/step
# Epoch 377/800
# 2/2 - 0s - loss: 0.8226 - 8ms/epoch - 4ms/step
# Epoch 378/800
# 2/2 - 0s - loss: 0.8129 - 8ms/epoch - 4ms/step
# Epoch 379/800
# 2/2 - 0s - loss: 0.8126 - 7ms/epoch - 4ms/step
# Epoch 380/800
# 2/2 - 0s - loss: 0.8136 - 6ms/epoch - 3ms/step
# Epoch 381/800
# 2/2 - 0s - loss: 0.8016 - 6ms/epoch - 3ms/step
# Epoch 382/800
# 2/2 - 0s - loss: 0.8299 - 6ms/epoch - 3ms/step
# Epoch 383/800
# 2/2 - 0s - loss: 0.7913 - 6ms/epoch - 3ms/step
# Epoch 384/800
# 2/2 - 0s - loss: 0.8319 - 6ms/epoch - 3ms/step
# Epoch 385/800
# 2/2 - 0s - loss: 0.8165 - 6ms/epoch - 3ms/step
# Epoch 386/800
# 2/2 - 0s - loss: 0.7638 - 5ms/epoch - 3ms/step
# Epoch 387/800
# 2/2 - 0s - loss: 0.7930 - 6ms/epoch - 3ms/step
# Epoch 388/800
# 2/2 - 0s - loss: 0.7774 - 6ms/epoch - 3ms/step
# Epoch 389/800
# 2/2 - 0s - loss: 0.8163 - 6ms/epoch - 3ms/step
# Epoch 390/800
# 2/2 - 0s - loss: 0.8574 - 7ms/epoch - 4ms/step
# Epoch 391/800
# 2/2 - 0s - loss: 0.7786 - 6ms/epoch - 3ms/step
# Epoch 392/800
# 2/2 - 0s - loss: 0.7967 - 5ms/epoch - 2ms/step
# Epoch 393/800
# 2/2 - 0s - loss: 0.8133 - 5ms/epoch - 2ms/step
# Epoch 394/800
# 2/2 - 0s - loss: 0.8164 - 5ms/epoch - 3ms/step
# Epoch 395/800
# 2/2 - 0s - loss: 0.7674 - 7ms/epoch - 3ms/step
# Epoch 396/800
# 2/2 - 0s - loss: 0.8163 - 7ms/epoch - 3ms/step
# Epoch 397/800
# 2/2 - 0s - loss: 0.8009 - 8ms/epoch - 4ms/step
# Epoch 398/800
# 2/2 - 0s - loss: 0.8288 - 9ms/epoch - 5ms/step
# Epoch 399/800
# 2/2 - 0s - loss: 0.8106 - 7ms/epoch - 4ms/step
# Epoch 400/800
# 2/2 - 0s - loss: 0.8266 - 6ms/epoch - 3ms/step
# Epoch 401/800
# 2/2 - 0s - loss: 0.7737 - 6ms/epoch - 3ms/step
# Epoch 402/800
# 2/2 - 0s - loss: 0.7933 - 9ms/epoch - 4ms/step
# Epoch 403/800
# 2/2 - 0s - loss: 0.7995 - 6ms/epoch - 3ms/step
# Epoch 404/800
# 2/2 - 0s - loss: 0.8031 - 5ms/epoch - 3ms/step
# Epoch 405/800
# 2/2 - 0s - loss: 0.8276 - 5ms/epoch - 3ms/step
# Epoch 406/800
# 2/2 - 0s - loss: 0.7906 - 5ms/epoch - 3ms/step
# Epoch 407/800
# 2/2 - 0s - loss: 0.7976 - 5ms/epoch - 3ms/step
# Epoch 408/800
# 2/2 - 0s - loss: 0.7868 - 7ms/epoch - 3ms/step
# Epoch 409/800
# 2/2 - 0s - loss: 0.8165 - 6ms/epoch - 3ms/step
# Epoch 410/800
# 2/2 - 0s - loss: 0.7898 - 5ms/epoch - 3ms/step
# Epoch 411/800
# 2/2 - 0s - loss: 0.7778 - 5ms/epoch - 2ms/step
# Epoch 412/800
# 2/2 - 0s - loss: 0.8099 - 6ms/epoch - 3ms/step
# Epoch 413/800
# 2/2 - 0s - loss: 0.8484 - 5ms/epoch - 3ms/step
# Epoch 414/800
# 2/2 - 0s - loss: 0.8178 - 6ms/epoch - 3ms/step
# Epoch 415/800
# 2/2 - 0s - loss: 0.7738 - 6ms/epoch - 3ms/step
# Epoch 416/800
# 2/2 - 0s - loss: 0.8679 - 5ms/epoch - 3ms/step
# Epoch 417/800
# 2/2 - 0s - loss: 0.8126 - 6ms/epoch - 3ms/step
# Epoch 418/800
# 2/2 - 0s - loss: 0.8257 - 7ms/epoch - 4ms/step
# Epoch 419/800
# 2/2 - 0s - loss: 0.8178 - 5ms/epoch - 3ms/step
# Epoch 420/800
# 2/2 - 0s - loss: 0.8148 - 5ms/epoch - 3ms/step
# Epoch 421/800
# 2/2 - 0s - loss: 0.8327 - 6ms/epoch - 3ms/step
# Epoch 422/800
# 2/2 - 0s - loss: 0.8132 - 6ms/epoch - 3ms/step
# Epoch 423/800
# 2/2 - 0s - loss: 0.8031 - 6ms/epoch - 3ms/step
# Epoch 424/800
# 2/2 - 0s - loss: 0.8028 - 5ms/epoch - 2ms/step
# Epoch 425/800
# 2/2 - 0s - loss: 0.8043 - 5ms/epoch - 3ms/step
# Epoch 426/800
# 2/2 - 0s - loss: 0.7991 - 7ms/epoch - 4ms/step
# Epoch 427/800
# 2/2 - 0s - loss: 0.7950 - 7ms/epoch - 4ms/step
# Epoch 428/800
# 2/2 - 0s - loss: 0.8368 - 7ms/epoch - 4ms/step
# Epoch 429/800
# 2/2 - 0s - loss: 0.8036 - 5ms/epoch - 3ms/step
# Epoch 430/800
# 2/2 - 0s - loss: 0.8218 - 5ms/epoch - 3ms/step
# Epoch 431/800
# 2/2 - 0s - loss: 0.8306 - 6ms/epoch - 3ms/step
# Epoch 432/800
# 2/2 - 0s - loss: 0.7977 - 6ms/epoch - 3ms/step
# Epoch 433/800
# 2/2 - 0s - loss: 0.8552 - 6ms/epoch - 3ms/step
# Epoch 434/800
# 2/2 - 0s - loss: 0.8232 - 6ms/epoch - 3ms/step
# Epoch 435/800
# 2/2 - 0s - loss: 0.8040 - 7ms/epoch - 4ms/step
# Epoch 436/800
# 2/2 - 0s - loss: 0.8042 - 8ms/epoch - 4ms/step
# Epoch 437/800
# 2/2 - 0s - loss: 0.7871 - 10ms/epoch - 5ms/step
# Epoch 438/800
# 2/2 - 0s - loss: 0.8063 - 7ms/epoch - 4ms/step
# Epoch 439/800
# 2/2 - 0s - loss: 0.8149 - 9ms/epoch - 4ms/step
# Epoch 440/800
# 2/2 - 0s - loss: 0.8043 - 8ms/epoch - 4ms/step
# Epoch 441/800
# 2/2 - 0s - loss: 0.8153 - 9ms/epoch - 4ms/step
# Epoch 442/800
# 2/2 - 0s - loss: 0.8128 - 7ms/epoch - 3ms/step
# Epoch 443/800
# 2/2 - 0s - loss: 0.7888 - 7ms/epoch - 4ms/step
# Epoch 444/800
# 2/2 - 0s - loss: 0.7954 - 6ms/epoch - 3ms/step
# Epoch 445/800
# 2/2 - 0s - loss: 0.7919 - 6ms/epoch - 3ms/step
# Epoch 446/800
# 2/2 - 0s - loss: 0.8079 - 7ms/epoch - 3ms/step
# Epoch 447/800
# 2/2 - 0s - loss: 0.7899 - 7ms/epoch - 3ms/step
# Epoch 448/800
# 2/2 - 0s - loss: 0.7902 - 7ms/epoch - 3ms/step
# Epoch 449/800
# 2/2 - 0s - loss: 0.7989 - 6ms/epoch - 3ms/step
# Epoch 450/800
# 2/2 - 0s - loss: 0.7670 - 6ms/epoch - 3ms/step
# Epoch 451/800
# 2/2 - 0s - loss: 0.7781 - 6ms/epoch - 3ms/step
# Epoch 452/800
# 2/2 - 0s - loss: 0.7840 - 6ms/epoch - 3ms/step
# Epoch 453/800
# 2/2 - 0s - loss: 0.8130 - 6ms/epoch - 3ms/step
# Epoch 454/800
# 2/2 - 0s - loss: 0.8220 - 5ms/epoch - 3ms/step
# Epoch 455/800
# 2/2 - 0s - loss: 0.7979 - 5ms/epoch - 3ms/step
# Epoch 456/800
# 2/2 - 0s - loss: 0.8169 - 6ms/epoch - 3ms/step
# Epoch 457/800
# 2/2 - 0s - loss: 0.8156 - 5ms/epoch - 3ms/step
# Epoch 458/800
# 2/2 - 0s - loss: 0.8160 - 5ms/epoch - 2ms/step
# Epoch 459/800
# 2/2 - 0s - loss: 0.8201 - 4ms/epoch - 2ms/step
# Epoch 460/800
# 2/2 - 0s - loss: 0.7720 - 4ms/epoch - 2ms/step
# Epoch 461/800
# 2/2 - 0s - loss: 0.8498 - 4ms/epoch - 2ms/step
# Epoch 462/800
# 2/2 - 0s - loss: 0.8162 - 5ms/epoch - 2ms/step
# Epoch 463/800
# 2/2 - 0s - loss: 0.8033 - 6ms/epoch - 3ms/step
# Epoch 464/800
# 2/2 - 0s - loss: 0.7862 - 5ms/epoch - 2ms/step
# Epoch 465/800
# 2/2 - 0s - loss: 0.7899 - 5ms/epoch - 2ms/step
# Epoch 466/800
# 2/2 - 0s - loss: 0.8150 - 7ms/epoch - 3ms/step
# Epoch 467/800
# 2/2 - 0s - loss: 0.8170 - 6ms/epoch - 3ms/step
# Epoch 468/800
# 2/2 - 0s - loss: 0.8268 - 7ms/epoch - 3ms/step
# Epoch 469/800
# 2/2 - 0s - loss: 0.8189 - 6ms/epoch - 3ms/step
# Epoch 470/800
# 2/2 - 0s - loss: 0.7917 - 6ms/epoch - 3ms/step
# Epoch 471/800
# 2/2 - 0s - loss: 0.8346 - 6ms/epoch - 3ms/step
# Epoch 472/800
# 2/2 - 0s - loss: 0.8441 - 7ms/epoch - 3ms/step
# Epoch 473/800
# 2/2 - 0s - loss: 0.7895 - 8ms/epoch - 4ms/step
# Epoch 474/800
# 2/2 - 0s - loss: 0.8285 - 8ms/epoch - 4ms/step
# Epoch 475/800
# 2/2 - 0s - loss: 0.7960 - 7ms/epoch - 4ms/step
# Epoch 476/800
# 2/2 - 0s - loss: 0.8262 - 8ms/epoch - 4ms/step
# Epoch 477/800
# 2/2 - 0s - loss: 0.8121 - 8ms/epoch - 4ms/step
# Epoch 478/800
# 2/2 - 0s - loss: 0.7674 - 8ms/epoch - 4ms/step
# Epoch 479/800
# 2/2 - 0s - loss: 0.7994 - 7ms/epoch - 3ms/step
# Epoch 480/800
# 2/2 - 0s - loss: 0.8052 - 7ms/epoch - 4ms/step
# Epoch 481/800
# 2/2 - 0s - loss: 0.8144 - 8ms/epoch - 4ms/step
# Epoch 482/800
# 2/2 - 0s - loss: 0.8120 - 7ms/epoch - 4ms/step
# Epoch 483/800
# 2/2 - 0s - loss: 0.7968 - 7ms/epoch - 4ms/step
# Epoch 484/800
# 2/2 - 0s - loss: 0.7898 - 6ms/epoch - 3ms/step
# Epoch 485/800
# 2/2 - 0s - loss: 0.7874 - 6ms/epoch - 3ms/step
# Epoch 486/800
# 2/2 - 0s - loss: 0.8252 - 5ms/epoch - 2ms/step
# Epoch 487/800
# 2/2 - 0s - loss: 0.8121 - 5ms/epoch - 2ms/step
# Epoch 488/800
# 2/2 - 0s - loss: 0.8201 - 5ms/epoch - 3ms/step
# Epoch 489/800
# 2/2 - 0s - loss: 0.8625 - 7ms/epoch - 4ms/step
# Epoch 490/800
# 2/2 - 0s - loss: 0.7679 - 5ms/epoch - 3ms/step
# Epoch 491/800
# 2/2 - 0s - loss: 0.8003 - 7ms/epoch - 4ms/step
# Epoch 492/800
# 2/2 - 0s - loss: 0.7830 - 7ms/epoch - 4ms/step
# Epoch 493/800
# 2/2 - 0s - loss: 0.8222 - 7ms/epoch - 3ms/step
# Epoch 494/800
# 2/2 - 0s - loss: 0.8013 - 6ms/epoch - 3ms/step
# Epoch 495/800
# 2/2 - 0s - loss: 0.8057 - 5ms/epoch - 3ms/step
# Epoch 496/800
# 2/2 - 0s - loss: 0.8036 - 6ms/epoch - 3ms/step
# Epoch 497/800
# 2/2 - 0s - loss: 0.7836 - 5ms/epoch - 2ms/step
# Epoch 498/800
# 2/2 - 0s - loss: 0.7866 - 5ms/epoch - 2ms/step
# Epoch 499/800
# 2/2 - 0s - loss: 0.7951 - 7ms/epoch - 3ms/step
# Epoch 500/800
# 2/2 - 0s - loss: 0.8053 - 6ms/epoch - 3ms/step
# Epoch 501/800
# 2/2 - 0s - loss: 0.7903 - 6ms/epoch - 3ms/step
# Epoch 502/800
# 2/2 - 0s - loss: 0.7853 - 7ms/epoch - 3ms/step
# Epoch 503/800
# 2/2 - 0s - loss: 0.8466 - 7ms/epoch - 3ms/step
# Epoch 504/800
# 2/2 - 0s - loss: 0.8298 - 6ms/epoch - 3ms/step
# Epoch 505/800
# 2/2 - 0s - loss: 0.7737 - 9ms/epoch - 4ms/step
# Epoch 506/800
# 2/2 - 0s - loss: 0.8001 - 8ms/epoch - 4ms/step
# Epoch 507/800
# 2/2 - 0s - loss: 0.8210 - 6ms/epoch - 3ms/step
# Epoch 508/800
# 2/2 - 0s - loss: 0.8081 - 5ms/epoch - 2ms/step
# Epoch 509/800
# 2/2 - 0s - loss: 0.8078 - 6ms/epoch - 3ms/step
# Epoch 510/800
# 2/2 - 0s - loss: 0.7660 - 6ms/epoch - 3ms/step
# Epoch 511/800
# 2/2 - 0s - loss: 0.7861 - 6ms/epoch - 3ms/step
# Epoch 512/800
# 2/2 - 0s - loss: 0.7879 - 5ms/epoch - 3ms/step
# Epoch 513/800
# 2/2 - 0s - loss: 0.8550 - 8ms/epoch - 4ms/step
# Epoch 514/800
# 2/2 - 0s - loss: 0.8395 - 5ms/epoch - 3ms/step
# Epoch 515/800
# 2/2 - 0s - loss: 0.7815 - 4ms/epoch - 2ms/step
# Epoch 516/800
# 2/2 - 0s - loss: 0.7949 - 4ms/epoch - 2ms/step
# Epoch 517/800
# 2/2 - 0s - loss: 0.7941 - 4ms/epoch - 2ms/step
# Epoch 518/800
# 2/2 - 0s - loss: 0.8290 - 5ms/epoch - 2ms/step
# Epoch 519/800
# 2/2 - 0s - loss: 0.8129 - 6ms/epoch - 3ms/step
# Epoch 520/800
# 2/2 - 0s - loss: 0.7751 - 6ms/epoch - 3ms/step
# Epoch 521/800
# 2/2 - 0s - loss: 0.7538 - 6ms/epoch - 3ms/step
# Epoch 522/800
# 2/2 - 0s - loss: 0.8189 - 5ms/epoch - 2ms/step
# Epoch 523/800
# 2/2 - 0s - loss: 0.8322 - 4ms/epoch - 2ms/step
# Epoch 524/800
# 2/2 - 0s - loss: 0.7912 - 4ms/epoch - 2ms/step
# Epoch 525/800
# 2/2 - 0s - loss: 0.7984 - 4ms/epoch - 2ms/step
# Epoch 526/800
# 2/2 - 0s - loss: 0.8179 - 4ms/epoch - 2ms/step
# Epoch 527/800
# 2/2 - 0s - loss: 0.8141 - 4ms/epoch - 2ms/step
# Epoch 528/800
# 2/2 - 0s - loss: 0.8087 - 4ms/epoch - 2ms/step
# Epoch 529/800
# 2/2 - 0s - loss: 0.8228 - 6ms/epoch - 3ms/step
# Epoch 530/800
# 2/2 - 0s - loss: 0.7732 - 6ms/epoch - 3ms/step
# Epoch 531/800
# 2/2 - 0s - loss: 0.8358 - 5ms/epoch - 3ms/step
# Epoch 532/800
# 2/2 - 0s - loss: 0.8084 - 6ms/epoch - 3ms/step
# Epoch 533/800
# 2/2 - 0s - loss: 0.8174 - 6ms/epoch - 3ms/step
# Epoch 534/800
# 2/2 - 0s - loss: 0.7760 - 6ms/epoch - 3ms/step
# Epoch 535/800
# 2/2 - 0s - loss: 0.8185 - 4ms/epoch - 2ms/step
# Epoch 536/800
# 2/2 - 0s - loss: 0.7957 - 5ms/epoch - 3ms/step
# Epoch 537/800
# 2/2 - 0s - loss: 0.8270 - 5ms/epoch - 2ms/step
# Epoch 538/800
# 2/2 - 0s - loss: 0.8268 - 6ms/epoch - 3ms/step
# Epoch 539/800
# 2/2 - 0s - loss: 0.8142 - 7ms/epoch - 3ms/step
# Epoch 540/800
# 2/2 - 0s - loss: 0.7801 - 5ms/epoch - 3ms/step
# Epoch 541/800
# 2/2 - 0s - loss: 0.7839 - 4ms/epoch - 2ms/step
# Epoch 542/800
# 2/2 - 0s - loss: 0.8092 - 7ms/epoch - 3ms/step
# Epoch 543/800
# 2/2 - 0s - loss: 0.8315 - 5ms/epoch - 2ms/step
# Epoch 544/800
# 2/2 - 0s - loss: 0.8145 - 4ms/epoch - 2ms/step
# Epoch 545/800
# 2/2 - 0s - loss: 0.8403 - 4ms/epoch - 2ms/step
# Epoch 546/800
# 2/2 - 0s - loss: 0.7898 - 4ms/epoch - 2ms/step
# Epoch 547/800
# 2/2 - 0s - loss: 0.8304 - 5ms/epoch - 3ms/step
# Epoch 548/800
# 2/2 - 0s - loss: 0.8001 - 5ms/epoch - 3ms/step
# Epoch 549/800
# 2/2 - 0s - loss: 0.7638 - 7ms/epoch - 3ms/step
# Epoch 550/800
# 2/2 - 0s - loss: 0.8261 - 6ms/epoch - 3ms/step
# Epoch 551/800
# 2/2 - 0s - loss: 0.8212 - 7ms/epoch - 3ms/step
# Epoch 552/800
# 2/2 - 0s - loss: 0.8032 - 7ms/epoch - 3ms/step
# Epoch 553/800
# 2/2 - 0s - loss: 0.8162 - 6ms/epoch - 3ms/step
# Epoch 554/800
# 2/2 - 0s - loss: 0.8012 - 6ms/epoch - 3ms/step
# Epoch 555/800
# 2/2 - 0s - loss: 0.8071 - 7ms/epoch - 3ms/step
# Epoch 556/800
# 2/2 - 0s - loss: 0.8036 - 6ms/epoch - 3ms/step
# Epoch 557/800
# 2/2 - 0s - loss: 0.8285 - 6ms/epoch - 3ms/step
# Epoch 558/800
# 2/2 - 0s - loss: 0.7795 - 5ms/epoch - 2ms/step
# Epoch 559/800
# 2/2 - 0s - loss: 0.8203 - 5ms/epoch - 3ms/step
# Epoch 560/800
# 2/2 - 0s - loss: 0.7816 - 6ms/epoch - 3ms/step
# Epoch 561/800
# 2/2 - 0s - loss: 0.7917 - 7ms/epoch - 3ms/step
# Epoch 562/800
# 2/2 - 0s - loss: 0.7895 - 8ms/epoch - 4ms/step
# Epoch 563/800
# 2/2 - 0s - loss: 0.7668 - 6ms/epoch - 3ms/step
# Epoch 564/800
# 2/2 - 0s - loss: 0.7840 - 7ms/epoch - 3ms/step
# Epoch 565/800
# 2/2 - 0s - loss: 0.8171 - 7ms/epoch - 3ms/step
# Epoch 566/800
# 2/2 - 0s - loss: 0.7964 - 7ms/epoch - 4ms/step
# Epoch 567/800
# 2/2 - 0s - loss: 0.8326 - 5ms/epoch - 3ms/step
# Epoch 568/800
# 2/2 - 0s - loss: 0.7891 - 6ms/epoch - 3ms/step
# Epoch 569/800
# 2/2 - 0s - loss: 0.7930 - 5ms/epoch - 2ms/step
# Epoch 570/800
# 2/2 - 0s - loss: 0.7723 - 6ms/epoch - 3ms/step
# Epoch 571/800
# 2/2 - 0s - loss: 0.7734 - 6ms/epoch - 3ms/step
# Epoch 572/800
# 2/2 - 0s - loss: 0.7776 - 6ms/epoch - 3ms/step
# Epoch 573/800
# 2/2 - 0s - loss: 0.8269 - 7ms/epoch - 4ms/step
# Epoch 574/800
# 2/2 - 0s - loss: 0.8272 - 6ms/epoch - 3ms/step
# Epoch 575/800
# 2/2 - 0s - loss: 0.7968 - 6ms/epoch - 3ms/step
# Epoch 576/800
# 2/2 - 0s - loss: 0.8236 - 8ms/epoch - 4ms/step
# Epoch 577/800
# 2/2 - 0s - loss: 0.7826 - 8ms/epoch - 4ms/step
# Epoch 578/800
# 2/2 - 0s - loss: 0.8279 - 5ms/epoch - 3ms/step
# Epoch 579/800
# 2/2 - 0s - loss: 0.8148 - 6ms/epoch - 3ms/step
# Epoch 580/800
# 2/2 - 0s - loss: 0.8058 - 5ms/epoch - 3ms/step
# Epoch 581/800
# 2/2 - 0s - loss: 0.7844 - 6ms/epoch - 3ms/step
# Epoch 582/800
# 2/2 - 0s - loss: 0.7801 - 7ms/epoch - 3ms/step
# Epoch 583/800
# 2/2 - 0s - loss: 0.8194 - 6ms/epoch - 3ms/step
# Epoch 584/800
# 2/2 - 0s - loss: 0.7737 - 6ms/epoch - 3ms/step
# Epoch 585/800
# 2/2 - 0s - loss: 0.8137 - 6ms/epoch - 3ms/step
# Epoch 586/800
# 2/2 - 0s - loss: 0.8220 - 6ms/epoch - 3ms/step
# Epoch 587/800
# 2/2 - 0s - loss: 0.8080 - 6ms/epoch - 3ms/step
# Epoch 588/800
# 2/2 - 0s - loss: 0.7620 - 5ms/epoch - 3ms/step
# Epoch 589/800
# 2/2 - 0s - loss: 0.8112 - 10ms/epoch - 5ms/step
# Epoch 590/800
# 2/2 - 0s - loss: 0.8097 - 11ms/epoch - 6ms/step
# Epoch 591/800
# 2/2 - 0s - loss: 0.8044 - 24ms/epoch - 12ms/step
# Epoch 592/800
# 2/2 - 0s - loss: 0.7959 - 13ms/epoch - 7ms/step
# Epoch 593/800
# 2/2 - 0s - loss: 0.8510 - 15ms/epoch - 7ms/step
# Epoch 594/800
# 2/2 - 0s - loss: 0.8076 - 6ms/epoch - 3ms/step
# Epoch 595/800
# 2/2 - 0s - loss: 0.8106 - 8ms/epoch - 4ms/step
# Epoch 596/800
# 2/2 - 0s - loss: 0.8261 - 7ms/epoch - 3ms/step
# Epoch 597/800
# 2/2 - 0s - loss: 0.7894 - 7ms/epoch - 3ms/step
# Epoch 598/800
# 2/2 - 0s - loss: 0.7914 - 6ms/epoch - 3ms/step
# Epoch 599/800
# 2/2 - 0s - loss: 0.8002 - 5ms/epoch - 3ms/step
# Epoch 600/800
# 2/2 - 0s - loss: 0.7849 - 7ms/epoch - 3ms/step
# Epoch 601/800
# 2/2 - 0s - loss: 0.7941 - 7ms/epoch - 4ms/step
# Epoch 602/800
# 2/2 - 0s - loss: 0.8148 - 6ms/epoch - 3ms/step
# Epoch 603/800
# 2/2 - 0s - loss: 0.8135 - 5ms/epoch - 2ms/step
# Epoch 604/800
# 2/2 - 0s - loss: 0.8018 - 5ms/epoch - 3ms/step
# Epoch 605/800
# 2/2 - 0s - loss: 0.8258 - 6ms/epoch - 3ms/step
# Epoch 606/800
# 2/2 - 0s - loss: 0.8069 - 5ms/epoch - 3ms/step
# Epoch 607/800
# 2/2 - 0s - loss: 0.8199 - 7ms/epoch - 3ms/step
# Epoch 608/800
# 2/2 - 0s - loss: 0.7998 - 5ms/epoch - 3ms/step
# Epoch 609/800
# 2/2 - 0s - loss: 0.7891 - 6ms/epoch - 3ms/step
# Epoch 610/800
# 2/2 - 0s - loss: 0.8051 - 7ms/epoch - 3ms/step
# Epoch 611/800
# 2/2 - 0s - loss: 0.7964 - 6ms/epoch - 3ms/step
# Epoch 612/800
# 2/2 - 0s - loss: 0.8285 - 8ms/epoch - 4ms/step
# Epoch 613/800
# 2/2 - 0s - loss: 0.7971 - 8ms/epoch - 4ms/step
# Epoch 614/800
# 2/2 - 0s - loss: 0.8237 - 5ms/epoch - 3ms/step
# Epoch 615/800
# 2/2 - 0s - loss: 0.7989 - 6ms/epoch - 3ms/step
# Epoch 616/800
# 2/2 - 0s - loss: 0.8289 - 7ms/epoch - 4ms/step
# Epoch 617/800
# 2/2 - 0s - loss: 0.7881 - 7ms/epoch - 3ms/step
# Epoch 618/800
# 2/2 - 0s - loss: 0.8004 - 5ms/epoch - 3ms/step
# Epoch 619/800
# 2/2 - 0s - loss: 0.7813 - 7ms/epoch - 3ms/step
# Epoch 620/800
# 2/2 - 0s - loss: 0.8129 - 7ms/epoch - 3ms/step
# Epoch 621/800
# 2/2 - 0s - loss: 0.8223 - 8ms/epoch - 4ms/step
# Epoch 622/800
# 2/2 - 0s - loss: 0.7947 - 8ms/epoch - 4ms/step
# Epoch 623/800
# 2/2 - 0s - loss: 0.7959 - 6ms/epoch - 3ms/step
# Epoch 624/800
# 2/2 - 0s - loss: 0.7890 - 7ms/epoch - 4ms/step
# Epoch 625/800
# 2/2 - 0s - loss: 0.8019 - 7ms/epoch - 3ms/step
# Epoch 626/800
# 2/2 - 0s - loss: 0.8158 - 7ms/epoch - 3ms/step
# Epoch 627/800
# 2/2 - 0s - loss: 0.8029 - 8ms/epoch - 4ms/step
# Epoch 628/800
# 2/2 - 0s - loss: 0.7817 - 8ms/epoch - 4ms/step
# Epoch 629/800
# 2/2 - 0s - loss: 0.8094 - 8ms/epoch - 4ms/step
# Epoch 630/800
# 2/2 - 0s - loss: 0.7820 - 6ms/epoch - 3ms/step
# Epoch 631/800
# 2/2 - 0s - loss: 0.8054 - 6ms/epoch - 3ms/step
# Epoch 632/800
# 2/2 - 0s - loss: 0.7980 - 6ms/epoch - 3ms/step
# Epoch 633/800
# 2/2 - 0s - loss: 0.7882 - 9ms/epoch - 4ms/step
# Epoch 634/800
# 2/2 - 0s - loss: 0.7966 - 7ms/epoch - 4ms/step
# Epoch 635/800
# 2/2 - 0s - loss: 0.8345 - 6ms/epoch - 3ms/step
# Epoch 636/800
# 2/2 - 0s - loss: 0.8450 - 5ms/epoch - 3ms/step
# Epoch 637/800
# 2/2 - 0s - loss: 0.8080 - 5ms/epoch - 3ms/step
# Epoch 638/800
# 2/2 - 0s - loss: 0.7745 - 7ms/epoch - 3ms/step
# Epoch 639/800
# 2/2 - 0s - loss: 0.8125 - 6ms/epoch - 3ms/step
# Epoch 640/800
# 2/2 - 0s - loss: 0.8044 - 8ms/epoch - 4ms/step
# Epoch 641/800
# 2/2 - 0s - loss: 0.8475 - 5ms/epoch - 2ms/step
# Epoch 642/800
# 2/2 - 0s - loss: 0.7989 - 6ms/epoch - 3ms/step
# Epoch 643/800
# 2/2 - 0s - loss: 0.8112 - 4ms/epoch - 2ms/step
# Epoch 644/800
# 2/2 - 0s - loss: 0.7820 - 6ms/epoch - 3ms/step
# Epoch 645/800
# 2/2 - 0s - loss: 0.8118 - 6ms/epoch - 3ms/step
# Epoch 646/800
# 2/2 - 0s - loss: 0.8189 - 7ms/epoch - 3ms/step
# Epoch 647/800
# 2/2 - 0s - loss: 0.8198 - 7ms/epoch - 3ms/step
# Epoch 648/800
# 2/2 - 0s - loss: 0.7786 - 7ms/epoch - 3ms/step
# Epoch 649/800
# 2/2 - 0s - loss: 0.8545 - 7ms/epoch - 4ms/step
# Epoch 650/800
# 2/2 - 0s - loss: 0.7735 - 6ms/epoch - 3ms/step
# Epoch 651/800
# 2/2 - 0s - loss: 0.8044 - 6ms/epoch - 3ms/step
# Epoch 652/800
# 2/2 - 0s - loss: 0.7703 - 5ms/epoch - 3ms/step
# Epoch 653/800
# 2/2 - 0s - loss: 0.8186 - 5ms/epoch - 3ms/step
# Epoch 654/800
# 2/2 - 0s - loss: 0.8159 - 6ms/epoch - 3ms/step
# Epoch 655/800
# 2/2 - 0s - loss: 0.7940 - 6ms/epoch - 3ms/step
# Epoch 656/800
# 2/2 - 0s - loss: 0.8082 - 6ms/epoch - 3ms/step
# Epoch 657/800
# 2/2 - 0s - loss: 0.8117 - 6ms/epoch - 3ms/step
# Epoch 658/800
# 2/2 - 0s - loss: 0.7794 - 6ms/epoch - 3ms/step
# Epoch 659/800
# 2/2 - 0s - loss: 0.7940 - 6ms/epoch - 3ms/step
# Epoch 660/800
# 2/2 - 0s - loss: 0.8121 - 5ms/epoch - 3ms/step
# Epoch 661/800
# 2/2 - 0s - loss: 0.8140 - 6ms/epoch - 3ms/step
# Epoch 662/800
# 2/2 - 0s - loss: 0.8148 - 5ms/epoch - 3ms/step
# Epoch 663/800
# 2/2 - 0s - loss: 0.8018 - 6ms/epoch - 3ms/step
# Epoch 664/800
# 2/2 - 0s - loss: 0.8227 - 6ms/epoch - 3ms/step
# Epoch 665/800
# 2/2 - 0s - loss: 0.7990 - 6ms/epoch - 3ms/step
# Epoch 666/800
# 2/2 - 0s - loss: 0.8344 - 7ms/epoch - 3ms/step
# Epoch 667/800
# 2/2 - 0s - loss: 0.7852 - 7ms/epoch - 3ms/step
# Epoch 668/800
# 2/2 - 0s - loss: 0.8153 - 6ms/epoch - 3ms/step
# Epoch 669/800
# 2/2 - 0s - loss: 0.8369 - 7ms/epoch - 3ms/step
# Epoch 670/800
# 2/2 - 0s - loss: 0.7726 - 7ms/epoch - 3ms/step
# Epoch 671/800
# 2/2 - 0s - loss: 0.8297 - 5ms/epoch - 2ms/step
# Epoch 672/800
# 2/2 - 0s - loss: 0.8116 - 6ms/epoch - 3ms/step
# Epoch 673/800
# 2/2 - 0s - loss: 0.8019 - 6ms/epoch - 3ms/step
# Epoch 674/800
# 2/2 - 0s - loss: 0.8476 - 6ms/epoch - 3ms/step
# Epoch 675/800
# 2/2 - 0s - loss: 0.7974 - 7ms/epoch - 3ms/step
# Epoch 676/800
# 2/2 - 0s - loss: 0.8181 - 6ms/epoch - 3ms/step
# Epoch 677/800
# 2/2 - 0s - loss: 0.7674 - 6ms/epoch - 3ms/step
# Epoch 678/800
# 2/2 - 0s - loss: 0.7992 - 6ms/epoch - 3ms/step
# Epoch 679/800
# 2/2 - 0s - loss: 0.7857 - 5ms/epoch - 2ms/step
# Epoch 680/800
# 2/2 - 0s - loss: 0.8174 - 5ms/epoch - 2ms/step
# Epoch 681/800
# 2/2 - 0s - loss: 0.8197 - 7ms/epoch - 4ms/step
# Epoch 682/800
# 2/2 - 0s - loss: 0.7880 - 5ms/epoch - 3ms/step
# Epoch 683/800
# 2/2 - 0s - loss: 0.8060 - 6ms/epoch - 3ms/step
# Epoch 684/800
# 2/2 - 0s - loss: 0.8062 - 6ms/epoch - 3ms/step
# Epoch 685/800
# 2/2 - 0s - loss: 0.7951 - 7ms/epoch - 3ms/step
# Epoch 686/800
# 2/2 - 0s - loss: 0.8242 - 6ms/epoch - 3ms/step
# Epoch 687/800
# 2/2 - 0s - loss: 0.7974 - 6ms/epoch - 3ms/step
# Epoch 688/800
# 2/2 - 0s - loss: 0.8490 - 8ms/epoch - 4ms/step
# Epoch 689/800
# 2/2 - 0s - loss: 0.8136 - 7ms/epoch - 3ms/step
# Epoch 690/800
# 2/2 - 0s - loss: 0.7979 - 6ms/epoch - 3ms/step
# Epoch 691/800
# 2/2 - 0s - loss: 0.8110 - 6ms/epoch - 3ms/step
# Epoch 692/800
# 2/2 - 0s - loss: 0.7986 - 6ms/epoch - 3ms/step
# Epoch 693/800
# 2/2 - 0s - loss: 0.8030 - 8ms/epoch - 4ms/step
# Epoch 694/800
# 2/2 - 0s - loss: 0.8336 - 8ms/epoch - 4ms/step
# Epoch 695/800
# 2/2 - 0s - loss: 0.7947 - 7ms/epoch - 4ms/step
# Epoch 696/800
# 2/2 - 0s - loss: 0.8414 - 6ms/epoch - 3ms/step
# Epoch 697/800
# 2/2 - 0s - loss: 0.7839 - 6ms/epoch - 3ms/step
# Epoch 698/800
# 2/2 - 0s - loss: 0.8246 - 7ms/epoch - 3ms/step
# Epoch 699/800
# 2/2 - 0s - loss: 0.7637 - 5ms/epoch - 3ms/step
# Epoch 700/800
# 2/2 - 0s - loss: 0.8071 - 7ms/epoch - 3ms/step
# Epoch 701/800
# 2/2 - 0s - loss: 0.8322 - 9ms/epoch - 4ms/step
# Epoch 702/800
# 2/2 - 0s - loss: 0.7827 - 7ms/epoch - 3ms/step
# Epoch 703/800
# 2/2 - 0s - loss: 0.8312 - 5ms/epoch - 3ms/step
# Epoch 704/800
# 2/2 - 0s - loss: 0.8067 - 5ms/epoch - 2ms/step
# Epoch 705/800
# 2/2 - 0s - loss: 0.8015 - 5ms/epoch - 2ms/step
# Epoch 706/800
# 2/2 - 0s - loss: 0.8076 - 7ms/epoch - 3ms/step
# Epoch 707/800
# 2/2 - 0s - loss: 0.7776 - 7ms/epoch - 3ms/step
# Epoch 708/800
# 2/2 - 0s - loss: 0.8104 - 6ms/epoch - 3ms/step
# Epoch 709/800
# 2/2 - 0s - loss: 0.8029 - 6ms/epoch - 3ms/step
# Epoch 710/800
# 2/2 - 0s - loss: 0.7911 - 7ms/epoch - 4ms/step
# Epoch 711/800
# 2/2 - 0s - loss: 0.7922 - 8ms/epoch - 4ms/step
# Epoch 712/800
# 2/2 - 0s - loss: 0.7697 - 7ms/epoch - 4ms/step
# Epoch 713/800
# 2/2 - 0s - loss: 0.8304 - 7ms/epoch - 3ms/step
# Epoch 714/800
# 2/2 - 0s - loss: 0.7983 - 5ms/epoch - 3ms/step
# Epoch 715/800
# 2/2 - 0s - loss: 0.8022 - 5ms/epoch - 2ms/step
# Epoch 716/800
# 2/2 - 0s - loss: 0.7635 - 5ms/epoch - 2ms/step
# Epoch 717/800
# 2/2 - 0s - loss: 0.7633 - 5ms/epoch - 2ms/step
# Epoch 718/800
# 2/2 - 0s - loss: 0.8288 - 6ms/epoch - 3ms/step
# Epoch 719/800
# 2/2 - 0s - loss: 0.8115 - 6ms/epoch - 3ms/step
# Epoch 720/800
# 2/2 - 0s - loss: 0.8137 - 5ms/epoch - 3ms/step
# Epoch 721/800
# 2/2 - 0s - loss: 0.7886 - 6ms/epoch - 3ms/step
# Epoch 722/800
# 2/2 - 0s - loss: 0.8198 - 5ms/epoch - 3ms/step
# Epoch 723/800
# 2/2 - 0s - loss: 0.8283 - 4ms/epoch - 2ms/step
# Epoch 724/800
# 2/2 - 0s - loss: 0.7906 - 7ms/epoch - 3ms/step
# Epoch 725/800
# 2/2 - 0s - loss: 0.8078 - 8ms/epoch - 4ms/step
# Epoch 726/800
# 2/2 - 0s - loss: 0.8156 - 7ms/epoch - 4ms/step
# Epoch 727/800
# 2/2 - 0s - loss: 0.8358 - 5ms/epoch - 3ms/step
# Epoch 728/800
# 2/2 - 0s - loss: 0.7946 - 24ms/epoch - 12ms/step
# Epoch 729/800
# 2/2 - 0s - loss: 0.8016 - 16ms/epoch - 8ms/step
# Epoch 730/800
# 2/2 - 0s - loss: 0.8178 - 13ms/epoch - 7ms/step
# Epoch 731/800
# 2/2 - 0s - loss: 0.8089 - 13ms/epoch - 7ms/step
# Epoch 732/800
# 2/2 - 0s - loss: 0.8028 - 7ms/epoch - 4ms/step
# Epoch 733/800
# 2/2 - 0s - loss: 0.8391 - 6ms/epoch - 3ms/step
# Epoch 734/800
# 2/2 - 0s - loss: 0.8088 - 8ms/epoch - 4ms/step
# Epoch 735/800
# 2/2 - 0s - loss: 0.8001 - 7ms/epoch - 3ms/step
# Epoch 736/800
# 2/2 - 0s - loss: 0.8114 - 6ms/epoch - 3ms/step
# Epoch 737/800
# 2/2 - 0s - loss: 0.7838 - 6ms/epoch - 3ms/step
# Epoch 738/800
# 2/2 - 0s - loss: 0.8217 - 6ms/epoch - 3ms/step
# Epoch 739/800
# 2/2 - 0s - loss: 0.7742 - 8ms/epoch - 4ms/step
# Epoch 740/800
# 2/2 - 0s - loss: 0.8237 - 8ms/epoch - 4ms/step
# Epoch 741/800
# 2/2 - 0s - loss: 0.7874 - 7ms/epoch - 3ms/step
# Epoch 742/800
# 2/2 - 0s - loss: 0.8091 - 7ms/epoch - 4ms/step
# Epoch 743/800
# 2/2 - 0s - loss: 0.8046 - 9ms/epoch - 5ms/step
# Epoch 744/800
# 2/2 - 0s - loss: 0.7626 - 7ms/epoch - 3ms/step
# Epoch 745/800
# 2/2 - 0s - loss: 0.8141 - 6ms/epoch - 3ms/step
# Epoch 746/800
# 2/2 - 0s - loss: 0.7763 - 7ms/epoch - 3ms/step
# Epoch 747/800
# 2/2 - 0s - loss: 0.8130 - 7ms/epoch - 4ms/step
# Epoch 748/800
# 2/2 - 0s - loss: 0.8144 - 6ms/epoch - 3ms/step
# Epoch 749/800
# 2/2 - 0s - loss: 0.7768 - 6ms/epoch - 3ms/step
# Epoch 750/800
# 2/2 - 0s - loss: 0.7575 - 5ms/epoch - 3ms/step
# Epoch 751/800
# 2/2 - 0s - loss: 0.8452 - 6ms/epoch - 3ms/step
# Epoch 752/800
# 2/2 - 0s - loss: 0.8375 - 6ms/epoch - 3ms/step
# Epoch 753/800
# 2/2 - 0s - loss: 0.7821 - 4ms/epoch - 2ms/step
# Epoch 754/800
# 2/2 - 0s - loss: 0.8203 - 7ms/epoch - 4ms/step
# Epoch 755/800
# 2/2 - 0s - loss: 0.7730 - 7ms/epoch - 3ms/step
# Epoch 756/800
# 2/2 - 0s - loss: 0.8097 - 7ms/epoch - 3ms/step
# Epoch 757/800
# 2/2 - 0s - loss: 0.8358 - 4ms/epoch - 2ms/step
# Epoch 758/800
# 2/2 - 0s - loss: 0.8163 - 5ms/epoch - 2ms/step
# Epoch 759/800
# 2/2 - 0s - loss: 0.8481 - 5ms/epoch - 3ms/step
# Epoch 760/800
# 2/2 - 0s - loss: 0.7803 - 6ms/epoch - 3ms/step
# Epoch 761/800
# 2/2 - 0s - loss: 0.8424 - 5ms/epoch - 3ms/step
# Epoch 762/800
# 2/2 - 0s - loss: 0.7926 - 8ms/epoch - 4ms/step
# Epoch 763/800
# 2/2 - 0s - loss: 0.8008 - 7ms/epoch - 4ms/step
# Epoch 764/800
# 2/2 - 0s - loss: 0.8165 - 5ms/epoch - 2ms/step
# Epoch 765/800
# 2/2 - 0s - loss: 0.7932 - 6ms/epoch - 3ms/step
# Epoch 766/800
# 2/2 - 0s - loss: 0.7726 - 6ms/epoch - 3ms/step
# Epoch 767/800
# 2/2 - 0s - loss: 0.8048 - 6ms/epoch - 3ms/step
# Epoch 768/800
# 2/2 - 0s - loss: 0.8075 - 6ms/epoch - 3ms/step
# Epoch 769/800
# 2/2 - 0s - loss: 0.7931 - 6ms/epoch - 3ms/step
# Epoch 770/800
# 2/2 - 0s - loss: 0.7762 - 5ms/epoch - 2ms/step
# Epoch 771/800
# 2/2 - 0s - loss: 0.7587 - 6ms/epoch - 3ms/step
# Epoch 772/800
# 2/2 - 0s - loss: 0.7751 - 5ms/epoch - 3ms/step
# Epoch 773/800
# 2/2 - 0s - loss: 0.8070 - 6ms/epoch - 3ms/step
# Epoch 774/800
# 2/2 - 0s - loss: 0.8529 - 5ms/epoch - 2ms/step
# Epoch 775/800
# 2/2 - 0s - loss: 0.8453 - 6ms/epoch - 3ms/step
# Epoch 776/800
# 2/2 - 0s - loss: 0.8061 - 7ms/epoch - 3ms/step
# Epoch 777/800
# 2/2 - 0s - loss: 0.8100 - 6ms/epoch - 3ms/step
# Epoch 778/800
# 2/2 - 0s - loss: 0.8020 - 8ms/epoch - 4ms/step
# Epoch 779/800
# 2/2 - 0s - loss: 0.8069 - 7ms/epoch - 3ms/step
# Epoch 780/800
# 2/2 - 0s - loss: 0.7903 - 7ms/epoch - 4ms/step
# Epoch 781/800
# 2/2 - 0s - loss: 0.7766 - 8ms/epoch - 4ms/step
# Epoch 782/800
# 2/2 - 0s - loss: 0.8032 - 8ms/epoch - 4ms/step
# Epoch 783/800
# 2/2 - 0s - loss: 0.7770 - 7ms/epoch - 3ms/step
# Epoch 784/800
# 2/2 - 0s - loss: 0.8150 - 7ms/epoch - 3ms/step
# Epoch 785/800
# 2/2 - 0s - loss: 0.7784 - 7ms/epoch - 4ms/step
# Epoch 786/800
# 2/2 - 0s - loss: 0.7716 - 6ms/epoch - 3ms/step
# Epoch 787/800
# 2/2 - 0s - loss: 0.8239 - 6ms/epoch - 3ms/step
# Epoch 788/800
# 2/2 - 0s - loss: 0.8050 - 5ms/epoch - 3ms/step
# Epoch 789/800
# 2/2 - 0s - loss: 0.8323 - 6ms/epoch - 3ms/step
# Epoch 790/800
# 2/2 - 0s - loss: 0.7983 - 5ms/epoch - 3ms/step
# Epoch 791/800
# 2/2 - 0s - loss: 0.8139 - 6ms/epoch - 3ms/step
# Epoch 792/800
# 2/2 - 0s - loss: 0.8014 - 6ms/epoch - 3ms/step
# Epoch 793/800
# 2/2 - 0s - loss: 0.7830 - 6ms/epoch - 3ms/step
# Epoch 794/800
# 2/2 - 0s - loss: 0.8210 - 5ms/epoch - 2ms/step
# Epoch 795/800
# 2/2 - 0s - loss: 0.7868 - 5ms/epoch - 2ms/step
# Epoch 796/800
# 2/2 - 0s - loss: 0.8622 - 7ms/epoch - 3ms/step
# Epoch 797/800
# 2/2 - 0s - loss: 0.8107 - 7ms/epoch - 4ms/step
# Epoch 798/800
# 2/2 - 0s - loss: 0.7465 - 6ms/epoch - 3ms/step
# Epoch 799/800
# 2/2 - 0s - loss: 0.8104 - 6ms/epoch - 3ms/step
# Epoch 800/800
# 2/2 - 0s - loss: 0.8123 - 5ms/epoch - 3ms/step

# %%
from sklearn.metrics import mean_squared_error

# %%
def mse(actual, predicted):
    actual = np.array(actual)
    predicted = np.array(predicted)
    differences = np.subtract(actual, predicted)
    squared_differences = np.square(differences)
    return squared_differences.mean()

# %%
#Predicciones  modelos
y_test_pred_dist = nngp_model(X_test_windowed)

for data_test,prediction_data,original in zip(X_test_windowed,y_test_pred_dist,y_test_windowed):
    inverse_y_pred = scaler_y.inverse_transform(prediction_data.numpy().reshape(-1, 1))
    inverse_y_test = scaler_y.inverse_transform(original.reshape(-1, 1))
    prediccion_modelo = inverse_y_pred.squeeze()
    original = inverse_y_test.squeeze()
    
    # error = mse([original], [prediccion_modelo])
    
    
    X_test_mont = scaler_x.inverse_transform(data_test)
    display(pd.DataFrame(X_test_mont,columns=['MES','ANO','SEMANA']))
    display(pd.DataFrame({'Prediccion':[prediccion_modelo],'Orignal':[original]}))##,'Error':[error]}))
# Out:
#    MES     ANO  SEMANA
# 0  1.0  2023.0    52.0
# 1  1.0  2023.0     1.0
# 2  1.0  2023.0     2.0
# 3  1.0  2023.0     3.0
#   Prediccion   Orignal         Error
# 0  413553.97  394146.0  3.766693e+08
#    MES     ANO  SEMANA
# 0  1.0  2023.0     1.0
# 1  1.0  2023.0     2.0
# 2  1.0  2023.0     3.0
# 3  1.0  2023.0     4.0
#   Prediccion   Orignal         Error
# 0   415090.3  452245.0  1.380471e+09
#    MES     ANO  SEMANA
# 0  1.0  2023.0     2.0
# 1  1.0  2023.0     3.0
# 2  1.0  2023.0     4.0
# 3  2.0  2023.0     5.0
#   Prediccion   Orignal         Error
# 0   402198.3  511573.0  1.196282e+10
#    MES     ANO  SEMANA
# 0  1.0  2023.0     3.0
# 1  1.0  2023.0     4.0
# 2  2.0  2023.0     5.0
# 3  2.0  2023.0     6.0
#   Prediccion   Orignal         Error
# 0  409224.53  454124.0  2.015962e+09
#    MES     ANO  SEMANA
# 0  1.0  2023.0     4.0
# 1  2.0  2023.0     5.0
# 2  2.0  2023.0     6.0
# 3  2.0  2023.0     7.0
#   Prediccion   Orignal         Error
# 0  410024.16  419833.0  9.621342e+07
#    MES     ANO  SEMANA
# 0  2.0  2023.0     5.0
# 1  2.0  2023.0     6.0
# 2  2.0  2023.0     7.0
# 3  2.0  2023.0     8.0
#   Prediccion   Orignal         Error
# 0  398721.16  381386.0  3.005076e+08
#    MES     ANO  SEMANA
# 0  2.0  2023.0     6.0
# 1  2.0  2023.0     7.0
# 2  2.0  2023.0     8.0
# 3  3.0  2023.0     9.0
#   Prediccion   Orignal         Error
# 0   416645.0  353466.0  3.991586e+09
#    MES     ANO  SEMANA
# 0  2.0  2023.0     7.0
# 1  2.0  2023.0     8.0
# 2  3.0  2023.0     9.0
# 3  3.0  2023.0    10.0
#   Prediccion   Orignal         Error
# 0   419128.4  411243.0  6.217963e+07
#    MES     ANO  SEMANA
# 0  2.0  2023.0     8.0
# 1  3.0  2023.0     9.0
# 2  3.0  2023.0    10.0
# 3  3.0  2023.0    11.0
#   Prediccion   Orignal         Error
# 0   405091.4  388934.0  2.610618e+08
#    MES     ANO  SEMANA
# 0  3.0  2023.0     9.0
# 1  3.0  2023.0    10.0
# 2  3.0  2023.0    11.0
# 3  3.0  2023.0    12.0
#   Prediccion Orignal         Error
# 0   413783.3  7280.0  1.652449e+11

# %%
inverse_y_pred = scaler_y.inverse_transform(y_test_pred_dist.numpy())

# %%
inverse_y_test = scaler_y.inverse_transform(y_test_windowed)

# %%
date_y = pd.DataFrame({'predicciones':inverse_y_pred.reshape(-1),'teorico':inverse_y_test.reshape(-1)})

# %%
date_y
# Out:
#    predicciones   teorico
# 0  413553.96875  394146.0
# 1  415090.31250  452245.0
# 2  402198.31250  511573.0
# 3  409224.53125  454124.0
# 4  410024.15625  419833.0
# 5  398721.15625  381386.0
# 6  416645.00000  353466.0
# 7  419128.40625  411243.0
# 8  405091.40625  388934.0
# 9  413783.31250    7280.0

# %%
sbn.lineplot(data = date_y[['predicciones','teorico']])
# Out:
# <AxesSubplot: >
